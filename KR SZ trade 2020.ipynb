# %%
import os
import pandas as pd
os.environ['OMP_NUM_THREADS'] = '1'
import glob
import pymongo
import numpy as np
import pandas as pd
import pickle
import time
import gzip
import lzma
import pytz
import warnings
import glob
import datetime
from collections import defaultdict, OrderedDict
import pyarrow as pa
import pyarrow.parquet as pq
import io


def DB(host, db_name, user, passwd):
    auth_db = db_name if user not in ('admin', 'root') else 'admin'
    uri = 'mongodb://%s:%s@%s/?authSource=%s' % (user, passwd, host, auth_db)
    return DBObj(uri, db_name=db_name)


class DBObj(object):
    def __init__(self, uri, symbol_column='skey', db_name='white_db', version=3):
        self.db_name = db_name
        self.uri = uri
        self.client = pymongo.MongoClient(self.uri)
        self.db = self.client[self.db_name]
        self.chunk_size = 20000
        self.symbol_column = symbol_column
        self.date_column = 'date'
        self.version = version

    def parse_uri(self, uri):
        # mongodb://user:password@example.com
        return uri.strip().replace('mongodb://', '').strip('/').replace(':', ' ').replace('@', ' ').split(' ')

    def drop_table(self, table_name):
        self.db.drop_collection(table_name)

    def rename_table(self, old_table, new_table):
        self.db[old_table].rename(new_table)

    def write(self, table_name, df):
        if len(df) == 0: return

        multi_date = False

        if self.date_column in df.columns:
            date = str(df.head(1)[self.date_column].iloc[0])
            multi_date = len(df[self.date_column].unique()) > 1
        else:
            raise Exception('DataFrame should contain date column')

        collection = self.db[table_name]
        collection.create_index([('date', pymongo.ASCENDING), ('symbol', pymongo.ASCENDING)], background=True)
        collection.create_index([('symbol', pymongo.ASCENDING), ('date', pymongo.ASCENDING)], background=True)

        if multi_date:
            for (date, symbol), sub_df in df.groupby([self.date_column, self.symbol_column]):
                date = str(date)
                symbol = int(symbol)
                collection.delete_many({'date': date, 'symbol': symbol})
                self.write_single(collection, date, symbol, sub_df)
        else:
            for symbol, sub_df in df.groupby([self.symbol_column]):
                collection.delete_many({'date': date, 'symbol': symbol})
                self.write_single(collection, date, symbol, sub_df)

    def write_single(self, collection, date, symbol, df):
        for start in range(0, len(df), self.chunk_size):
            end = min(start + self.chunk_size, len(df))
            df_seg = df[start:end]
            version = self.version
            ser_data = self.ser(df_seg, version)
            seg = {'ver': version, 'data': ser_data, 'date': date, 'symbol': symbol, 'start': start}
            collection.insert_one(seg)

    def build_query(self, start_date=None, end_date=None, symbol=None):
        query = {}

        def parse_date(x):
            if type(x) == str:
                if len(x) != 8:
                    raise Exception("`date` must be YYYYMMDD format")
                return x
            elif type(x) == datetime.datetime or type(x) == datetime.date:
                return x.strftime("%Y%m%d")
            elif type(x) == int:
                return parse_date(str(x))
            else:
                raise Exception("invalid `date` type: " + str(type(x)))

        if start_date is not None or end_date is not None:
            query['date'] = {}
            if start_date is not None:
                query['date']['$gte'] = parse_date(start_date)
            if end_date is not None:
                query['date']['$lte'] = parse_date(end_date)

        def parse_symbol(x):
            if type(x) == int:
                return x
            else:
                return int(x)

        if symbol:
            if type(symbol) == list or type(symbol) == tuple:
                query['symbol'] = {'$in': [parse_symbol(x) for x in symbol]}
            else:
                query['symbol'] = parse_symbol(symbol)

        return query

    def delete(self, table_name, start_date=None, end_date=None, symbol=None):
        collection = self.db[table_name]

        query = self.build_query(start_date, end_date, symbol)
        if not query:
            print('cannot delete the whole table')
            return None

        collection.delete_many(query)

    def read(self, table_name, start_date=None, end_date=None, symbol=None):
        collection = self.db[table_name]

        query = self.build_query(start_date, end_date, symbol)
        if not query:
            print('cannot read the whole table')
            return None

        segs = []
        for x in collection.find(query):
            x['data'] = self.deser(x['data'], x['ver'])
            segs.append(x)
        segs.sort(key=lambda x: (x['symbol'], x['date'], x['start']))
        return pd.concat([x['data'] for x in segs], ignore_index=True) if segs else None
    
    def read_raw(self, table_name, start_date=None, end_date=None, symbol=None):
        collection = self.db[table_name]

        query = self.build_query(start_date, end_date, symbol)
        if not query:
            print('cannot read the whole table')
            return None

        return collection.find(query)

    def list_tables(self):
        return self.db.collection_names()

    def list_dates(self, table_name, start_date=None, end_date=None, symbol=None):
        collection = self.db[table_name]
        dates = set()
        if start_date is None:
            start_date = '00000000'
        if end_date is None:
            end_date = '99999999'
        for x in collection.find(self.build_query(start_date, end_date, symbol), {"date": 1, '_id': 0}):
            dates.add(x['date'])
        return sorted(list(dates))

    def ser(self, s, version):
        pickle_protocol = 4
        if version == 1:
            return gzip.compress(pickle.dumps(s, protocol=pickle_protocol), compresslevel=2)
        elif version == 2:
            return lzma.compress(pickle.dumps(s, protocol=pickle_protocol), preset=1)
        elif version == 3:
            # 32-bit number needs more space than 64-bit for parquet
            for col_name in s.columns:
                col = s[col_name]
                if col.dtype == np.int32:
                    s[col_name] = s[col_name].astype(np.int64)
                elif col.dtype == np.uint32:
                    s[col_name] = s[col_name].astype(np.uint64)
            tbl = pa.Table.from_pandas(s)
            f = io.BytesIO()
            pq.write_table(tbl, f, use_dictionary=False, compression='ZSTD', compression_level=0)
            f.seek(0)
            data = f.read()
            return data
        else:
            raise Exception('unknown version')

    def deser(self, s, version):
        def unpickle(s):
            return pickle.loads(s)
        if version == 1:
            return unpickle(gzip.decompress(s))
        elif version == 2:
            return unpickle(lzma.decompress(s))
        elif version == 3:
            f = io.BytesIO()
            f.write(s)
            f.seek(0)
            return pq.read_table(f, use_threads=False).to_pandas()
        else:
            raise Exception('unknown version')


def patch_pandas_pickle():
    if pd.__version__ < '0.24':
        import sys
        from types import ModuleType
        from pandas.core.internals import BlockManager
        pkg_name = 'pandas.core.internals.managers'
        if pkg_name not in sys.modules:
            m = ModuleType(pkg_name)
            m.BlockManager = BlockManager
            sys.modules[pkg_name] = m
patch_pandas_pickle()


            
            
            
            
            
            
            
            
import pandas as pd
import random
import numpy as np
import glob
import os
import pickle
import datetime
import time
pd.set_option("max_columns", 200)

startTm = datetime.datetime.now()
readPath = '/mnt/ShareWithServer/day_stock_20200820/***'
dataPathLs = np.array(glob.glob(readPath))
dataPathLs = dataPathLs[[np.array([os.path.basename(i).split('.')[0][:2] == 'SZ' for i in dataPathLs])]]
db = pd.DataFrame()
for p in dataPathLs:
    dayData = pd.read_csv(p, compression='gzip')
    db = pd.concat([db, dayData])
print(datetime.datetime.now() - startTm)

year = "2020"
startDate = '20200803'
endDate = '20200803'
readPath = '/mnt/Kevin_zhenyu/KR_daily_data/***'
dataPathLs = np.array(glob.glob(readPath))
dateLs = np.array([os.path.basename(i) for i in dataPathLs])
dataPathLs = dataPathLs[(dateLs >= startDate) & (dateLs <= endDate)]

for data in dataPathLs:
    readPath = data + '/SZ/tick/***'
    dataPathLs = np.array(glob.glob(readPath))
    dateLs = np.array([int(os.path.basename(i).split('.')[0]) for i in dataPathLs])
    dataPathLs = dataPathLs[(dateLs < 4000) | ((dateLs > 300000) & (dateLs < 310000))]
    TradeLog = []
    ll = []
    
    for i in dataPathLs:
        try:
            df = pd.read_csv(i)
        except:
            print("empty data")
            print(i)
            ll.append(int(os.path.basename(i).split('.')[0]))
            continue
        df["SecurityID"] = int(os.path.basename(i).split('.')[0])
        TradeLog += [df]
    TradeLog = pd.concat(TradeLog).reset_index(drop=True)
    TradeLog = TradeLog[TradeLog["ChannelNo"] != 4001]
    
    TradeLog["date"] = TradeLog["TransactTime"].iloc[0]//1000000000
    TradeLog = TradeLog.rename(columns={"Qty":"trade_qty", "Price":"trade_price", "ExecType":"trade_type"})
    TradeLog["trade_money"] = TradeLog["trade_price"] * TradeLog["trade_qty"]
    TradeLog["trade_flag"] = 0
    TradeLog["skey"] = TradeLog["SecurityID"] + 2000000
    TradeLog["clockAtArrival"] = TradeLog["TransactTime"].astype(str).apply(lambda x: np.int64(datetime.datetime.strptime(x, '%Y%m%d%H%M%S%f').timestamp()*1e6))
    TradeLog['datetime'] = TradeLog["clockAtArrival"].apply(lambda x: datetime.datetime.fromtimestamp(x/1e6))
    TradeLog["time"] = (TradeLog['TransactTime'] - int(TradeLog['TransactTime'].iloc[0]//1000000000*1000000000)).astype(np.int64)*1000
    TradeLog["trade_type"] = np.where(TradeLog["trade_type"] == 'F', 1, TradeLog["trade_type"])
    for col in ["skey", "date", "ApplSeqNum", "BidApplSeqNum", "OfferApplSeqNum", "trade_qty", "trade_type", "trade_flag"]:
        TradeLog[col] = TradeLog[col].astype('int32')
#     for cols in ["trade_money", "trade_price"]:
#         display(cols)
#         display(TradeLog[cols].astype(str).apply(lambda x: len(str(x.split('.')[1]))).unique())
#         TradeLog[cols] = TradeLog[cols].round(2)
#         display(TradeLog[cols].astype(str).apply(lambda x: len(str(x.split('.')[1]))).unique())
    for cols in ["trade_money"]:
        TradeLog[cols] = TradeLog[cols].round(2)
    
    da_te = str(TradeLog["date"].iloc[0]) 
    da_te = da_te[:4] + '-' + da_te[4:6] + '-' + da_te[6:8]
    db1 = db[db["date"] == da_te]
    sl = (db1["ID"].str[2:].astype(int) + 2000000).unique()
    db1["max_volume"] = db1.groupby("ID")["d_volume"].transform("max")
    db1["max_amount"] = db1.groupby("ID")["d_amount"].transform("max")
    t1 = db1.groupby("ID")["max_volume", "max_amount"].first().reset_index()
    del db1
    t1["skey"] = t1["ID"].str[2:].astype(int) + 2000000
    trade1 = TradeLog[TradeLog["trade_type"] == 1].groupby("skey")["trade_qty"].sum().reset_index()
    trade1.columns=["skey", "cum_volume"]
    trade2 = TradeLog[TradeLog["trade_type"] == 1].groupby("skey")["trade_money"].sum().reset_index()
    trade2.columns=["skey", "cum_amount"]
    t2 = pd.merge(trade1, trade2, on="skey")
    re = pd.merge(t1, t2, on="skey", how="outer")
    try:
        assert(t1.shape[0] == t2.shape[0])
        assert(re[re["cum_volume"] != re["max_volume"]].shape[0] == 0)
        assert(re[re["cum_amount"].round(2) != re["max_amount"]].shape[0] == 0)
    except:
        display(set(t1["skey"]) - set(t2["skey"]))
        display(re[re["cum_volume"] != re["max_volume"]])
        display(re[re["cum_amount"].round(2) != re["max_amount"]])
    del t1
    del t2
    del re
 
    TradeLog = TradeLog[["skey", "date", "time", "clockAtArrival", "ApplSeqNum", "trade_type", "trade_flag",
                                                 "trade_price", "trade_qty", "BidApplSeqNum", "OfferApplSeqNum"]]
    print(da_te)
    print("trade finished")


    database_name = 'com_md_eq_cn'
    user = "zhenyuy"
    password = "bnONBrzSMGoE"

    db1 = DB("192.168.10.178", database_name, user, password)
    db1.write('md_trade', TradeLog)    
    
    del TradeLog

    print(datetime.datetime.now() - startTm)
# Out:
# /home/work516/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:242: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
# 0:08:39.336363
# /home/work516/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:301: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /home/work516/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:302: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /home/work516/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:303: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
# 2020-08-03
# trade finished
# /home/work516/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:180: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# 0:25:18.247530

# %%
import pymongo
import pandas as pd
import pickle
import datetime
import time
import gzip
import lzma
import pytz


def DB(host, db_name, user, passwd):
    auth_db = db_name if user not in ('admin', 'root') else 'admin'
    uri = 'mongodb://%s:%s@%s/?authSource=%s' % (user, passwd, host, auth_db)
    return DBObj(uri, db_name=db_name)


class DBObj(object):
    def __init__(self, uri, symbol_column='skey', db_name='white_db'):
        self.db_name = db_name
        self.uri = uri
        self.client = pymongo.MongoClient(self.uri)
        self.db = self.client[self.db_name]
        self.chunk_size = 20000
        self.symbol_column = symbol_column
        self.date_column = 'date'

    def parse_uri(self, uri):
        # mongodb://user:password@example.com
        return uri.strip().replace('mongodb://', '').strip('/').replace(':', ' ').replace('@', ' ').split(' ')

    def drop_table(self, table_name):
        self.db.drop_collection(table_name)

    def rename_table(self, old_table, new_table):
        self.db[old_table].rename(new_table)

    def write(self, table_name, df):
        if len(df) == 0: return

        multi_date = False

        if self.date_column in df.columns:
            date = str(df.head(1)[self.date_column].iloc[0])
            multi_date = len(df[self.date_column].unique()) > 1
        else:
            raise Exception('DataFrame should contain date column')

        collection = self.db[table_name]
        collection.create_index([('date', pymongo.ASCENDING), ('symbol', pymongo.ASCENDING)], background=True)
        collection.create_index([('symbol', pymongo.ASCENDING), ('date', pymongo.ASCENDING)], background=True)

        if multi_date:
            for (date, symbol), sub_df in df.groupby([self.date_column, self.symbol_column]):
                date = str(date)
                symbol = int(symbol)
                collection.delete_many({'date': date, 'symbol': symbol})
                self.write_single(collection, date, symbol, sub_df)
        else:
            for symbol, sub_df in df.groupby([self.symbol_column]):
                collection.delete_many({'date': date, 'symbol': symbol})
                self.write_single(collection, date, symbol, sub_df)

    def write_single(self, collection, date, symbol, df):
        for start in range(0, len(df), self.chunk_size):
            end = min(start + self.chunk_size, len(df))
            df_seg = df[start:end]
            version = 1
            seg = {'ver': version, 'data': self.ser(df_seg, version), 'date': date, 'symbol': symbol, 'start': start}
            collection.insert_one(seg)

    def build_query(self, start_date=None, end_date=None, symbol=None):
        query = {}

        def parse_date(x):
            if type(x) == str:
                if len(x) != 8:
                    raise Exception("`date` must be YYYYMMDD format")
                return x
            elif type(x) == datetime.datetime or type(x) == datetime.date:
                return x.strftime("%Y%m%d")
            elif type(x) == int:
                return parse_date(str(x))
            else:
                raise Exception("invalid `date` type: " + str(type(x)))

        if start_date is not None or end_date is not None:
            query['date'] = {}
            if start_date is not None:
                query['date']['$gte'] = parse_date(start_date)
            if end_date is not None:
                query['date']['$lte'] = parse_date(end_date)

        def parse_symbol(x):
            if type(x) == int:
                return x
            else:
                return int(x)

        if symbol:
            if type(symbol) == list or type(symbol) == tuple:
                query['symbol'] = {'$in': [parse_symbol(x) for x in symbol]}
            else:
                query['symbol'] = parse_symbol(symbol)

        return query

    def delete(self, table_name, start_date=None, end_date=None, symbol=None):
        collection = self.db[table_name]

        query = self.build_query(start_date, end_date, symbol)
        if not query:
            print('cannot delete the whole table')
            return None

        collection.delete_many(query)

    def read(self, table_name, start_date=None, end_date=None, symbol=None):
        collection = self.db[table_name]

        query = self.build_query(start_date, end_date, symbol)
        if not query:
            print('cannot read the whole table')
            return None

        segs = []
        for x in collection.find(query):
            x['data'] = self.deser(x['data'], x['ver'])
            segs.append(x)
        segs.sort(key=lambda x: (x['symbol'], x['date'], x['start']))
        return pd.concat([x['data'] for x in segs], ignore_index=True) if segs else None

    def list_tables(self):
        return self.db.collection_names()

    def list_dates(self, table_name, start_date=None, end_date=None, symbol=None):
        collection = self.db[table_name]
        dates = set()
        if start_date is None:
            start_date = '00000000'
        if end_date is None:
            end_date = '99999999'
        for x in collection.find(self.build_query(start_date, end_date, symbol), {"date": 1, '_id': 0}):
            dates.add(x['date'])
        return sorted(list(dates))

    def ser(self, s, version):
        pickle_protocol = 4
        if version == 1:
            return gzip.compress(pickle.dumps(s, protocol=pickle_protocol), compresslevel=2)
        elif version == 2:
            return lzma.compress(pickle.dumps(s, protocol=pickle_protocol), preset=1)
        else:
            raise Exception('unknown version')

    def deser(self, s, version):
        def unpickle(s):
            return pickle.loads(s)

        if version == 1:
            return unpickle(gzip.decompress(s))
        elif version == 2:
            return unpickle(lzma.decompress(s))
        else:
            raise Exception('unknown version')


def patch_pandas_pickle():
    if pd.__version__ < '0.24':
        import sys
        from types import ModuleType
        from pandas.core.internals import BlockManager
        pkg_name = 'pandas.core.internals.managers'
        if pkg_name not in sys.modules:
            m = ModuleType(pkg_name)
            m.BlockManager = BlockManager
            sys.modules[pkg_name] = m
patch_pandas_pickle()


            
            
            
            
            
            
            
            
import pandas as pd
import random
import numpy as np
import glob
import os
import pickle
import datetime
import time
pd.set_option("max_columns", 200)

startTm = datetime.datetime.now()
readPath = '/home/work516/day_stock/***'
dataPathLs = np.array(glob.glob(readPath))
dataPathLs = dataPathLs[[np.array([os.path.basename(i).split('.')[0][:2] == 'SZ' for i in dataPathLs])]]
db = pd.DataFrame()
for p in dataPathLs:
    dayData = pd.read_csv(p, compression='gzip')
    db = pd.concat([db, dayData])
print(datetime.datetime.now() - startTm)

year = "2020"
startDate = '20200109'
endDate = '20200529'
readPath = '/mnt/usb/data/' + year + '/***/***'
dataPathLs = np.array(glob.glob(readPath))
dateLs = np.array([os.path.basename(i) for i in dataPathLs])
dataPathLs = dataPathLs[(dateLs >= startDate) & (dateLs <= endDate)]

for data in dataPathLs:
    
    if len(np.array(glob.glob(data + '/SZ/***'))) == 0:
        if int(os.path.basename(data)) not in date_list["Date"].values:
            continue
        else:
            print(os.path.basename(data) + " less data!!!!!!!!!!!!!!!!!")
            less.append(data)
            continue
    startTm = datetime.datetime.now()
    date = os.path.basename(data)
    rar_path = data + '/SZ/tick.7z'
    path = '/mnt/e/unzip_data/2020/SZ'
    path1 = path + '/' + date
    un_path = path1
    cmd = '7za x {} -o{}'.format(rar_path, un_path)
    os.system(cmd)
    print(datetime.datetime.now() - startTm)
    print(date + ' unzip finished')
    
    
    startTm = datetime.datetime.now()
    
    readPath = path1 + '/tick/***'
    dataPathLs = np.array(glob.glob(readPath))
    dateLs = np.array([int(os.path.basename(i).split('.')[0]) for i in dataPathLs])
    dataPathLs = dataPathLs[(dateLs < 4000) | ((dateLs > 300000) & (dateLs < 310000))]
    TradeLog = []
    ll = []
    
    for i in dataPathLs:
        try:
            df = pd.read_csv(i)
        except:
            print("empty data")
            print(i)
            ll.append(int(os.path.basename(i).split('.')[0]))
            continue
        df["SecurityID"] = int(os.path.basename(i).split('.')[0])
        TradeLog += [df]
    TradeLog = pd.concat(TradeLog).reset_index(drop=True)
    TradeLog = TradeLog[TradeLog["ChannelNo"] != 4001]
    
    TradeLog["date"] = TradeLog["TransactTime"].iloc[0]//1000000000
    TradeLog = TradeLog.rename(columns={"Qty":"trade_qty", "Price":"trade_price", "ExecType":"trade_type"})
    TradeLog["trade_money"] = TradeLog["trade_price"] * TradeLog["trade_qty"]
    TradeLog["trade_flag"] = 0
    TradeLog["skey"] = TradeLog["SecurityID"] + 2000000
    TradeLog["clockAtArrival"] = TradeLog["TransactTime"].astype(str).apply(lambda x: np.int64(datetime.datetime.strptime(x, '%Y%m%d%H%M%S%f').timestamp()*1e6))
    TradeLog['datetime'] = TradeLog["clockAtArrival"].apply(lambda x: datetime.datetime.fromtimestamp(x/1e6))
    TradeLog["time"] = (TradeLog['TransactTime'] - int(TradeLog['TransactTime'].iloc[0]//1000000000*1000000000)).astype(np.int64)*1000
    TradeLog["trade_type"] = np.where(TradeLog["trade_type"] == 'F', 1, TradeLog["trade_type"])
    for col in ["skey", "date", "ApplSeqNum", "BidApplSeqNum", "OfferApplSeqNum", "trade_qty", "trade_type", "trade_flag"]:
        TradeLog[col] = TradeLog[col].astype('int32')
#     for cols in ["trade_money", "trade_price"]:
#         display(cols)
#         display(TradeLog[cols].astype(str).apply(lambda x: len(str(x.split('.')[1]))).unique())
#         TradeLog[cols] = TradeLog[cols].round(2)
#         display(TradeLog[cols].astype(str).apply(lambda x: len(str(x.split('.')[1]))).unique())
    for cols in ["trade_money"]:
        TradeLog[cols] = TradeLog[cols].round(2)
    
    da_te = str(TradeLog["date"].iloc[0]) 
    da_te = da_te[:4] + '-' + da_te[4:6] + '-' + da_te[6:8]
    db1 = db[db["date"] == da_te]
    sl = (db1["ID"].str[2:].astype(int) + 2000000).unique()
    db1["max_volume"] = db1.groupby("ID")["d_volume"].transform("max")
    db1["max_amount"] = db1.groupby("ID")["d_amount"].transform("max")
    t1 = db1.groupby("ID")["max_volume", "max_amount"].first().reset_index()
    del db1
    t1["skey"] = t1["ID"].str[2:].astype(int) + 2000000
    trade1 = TradeLog[TradeLog["trade_type"] == 1].groupby("skey")["trade_qty"].sum().reset_index()
    trade1.columns=["skey", "cum_volume"]
    trade2 = TradeLog[TradeLog["trade_type"] == 1].groupby("skey")["trade_money"].sum().reset_index()
    trade2.columns=["skey", "cum_amount"]
    t2 = pd.merge(trade1, trade2, on="skey")
    re = pd.merge(t1, t2, on="skey", how="outer")
    try:
        assert(t1.shape[0] == t2.shape[0])
        assert(re[re["cum_volume"] != re["max_volume"]].shape[0] == 0)
        assert(re[re["cum_amount"].round(2) != re["max_amount"]].shape[0] == 0)
    except:
        display(set(t1["skey"]) - set(t2["skey"]))
        display(re[re["cum_volume"] != re["max_volume"]])
        display(re[re["cum_amount"].round(2) != re["max_amount"]])
    del t1
    del t2
    del re
 
    TradeLog = TradeLog[["skey", "date", "time", "clockAtArrival", "datetime", "ApplSeqNum", "trade_type", "trade_flag",
                                                 "trade_price", "trade_qty", "BidApplSeqNum", "OfferApplSeqNum"]]
    print(da_te)
    print("trade finished")


    database_name = 'com_md_eq_cn'
    user = "zhenyuy"
    password = "bnONBrzSMGoE"

    db1 = DB("192.168.10.223", database_name, user, password)
    db1.write('md_trade', TradeLog)    
    
    del TradeLog

    print(datetime.datetime.now() - startTm)
# Out:
# /home/work516/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:201: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
# 0:05:44.481435
# 0:00:00.372039
# 20200109 unzip finished
# /home/work516/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:282: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /home/work516/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:283: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /home/work516/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:284: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
# 2020-01-09
# trade finished
# 0:12:04.344354
# 0:00:00.485499
# 20200110 unzip finished
# 2020-01-10
# trade finished
# 0:10:47.494568
# 0:00:34.307719
# 20200113 unzip finished
# 2020-01-13
# trade finished
# 0:10:37.627474
# 0:00:36.368465
# 20200114 unzip finished
# 2020-01-14
# trade finished
# 0:10:58.233442
# 0:00:33.738996
# 20200115 unzip finished
# 2020-01-15
# trade finished
# 0:11:01.353976
# 0:00:31.068934
# 20200116 unzip finished
# 2020-01-16
# trade finished
# 0:09:55.706836
# 0:00:30.302293
# 20200117 unzip finished
# 2020-01-17
# trade finished
# 0:09:33.058346
# 0:00:31.196891
# 20200120 unzip finished
# 2020-01-20
# trade finished
# 0:09:57.885947
# 0:00:34.025310
# 20200121 unzip finished
# 2020-01-21
# trade finished
# 0:10:25.002092
# 0:00:33.197496
# 20200122 unzip finished
# 2020-01-22
# trade finished
# 0:10:45.403860
# 0:00:38.120436
# 20200123 unzip finished
# set()
#             ID   max_volume    max_amount     skey  cum_volume    cum_amount
# 19    SZ000026   14988714.0  1.571684e+08  2000026    14986014  1.571403e+08
# 604   SZ002151   30999166.0  8.406265e+08  2002151    30999066  8.406239e+08
# 696   SZ002243    8370992.0  1.224007e+08  2002243     8370592  1.223949e+08
# 830   SZ002379   43961587.0  1.708636e+08  2002379    43960587  1.708598e+08
# 874   SZ002423    4666510.0  4.216526e+07  2002423     4666410  4.216436e+07
# 906   SZ002456  218772484.0  4.009594e+09  2002456   218772384  4.009593e+09
# 910   SZ002460   59039851.0  2.553695e+09  2002460    59038751  2.553649e+09
# 1236  SZ002798    3673927.0  8.383923e+07  2002798     3673627  8.383249e+07
# 1364  SZ002937    5058576.0  7.852348e+07  2002937     5054576  7.846181e+07
# 1415  SZ300017   86463136.0  7.248101e+08  2300017    86462536  7.248052e+08
# 1494  SZ300098   66305403.0  3.530078e+08  2300098    66285403  3.529026e+08
# 1827  SZ300438   15452528.0  4.389533e+08  2300438    15450528  4.388980e+08
# 1869  SZ300480   12561599.0  2.469841e+08  2300480    12556599  2.468911e+08
#             ID   max_volume    max_amount     skey  cum_volume    cum_amount
# 19    SZ000026   14988714.0  1.571684e+08  2000026    14986014  1.571403e+08
# 604   SZ002151   30999166.0  8.406265e+08  2002151    30999066  8.406239e+08
# 696   SZ002243    8370992.0  1.224007e+08  2002243     8370592  1.223949e+08
# 830   SZ002379   43961587.0  1.708636e+08  2002379    43960587  1.708598e+08
# 874   SZ002423    4666510.0  4.216526e+07  2002423     4666410  4.216436e+07
# 906   SZ002456  218772484.0  4.009594e+09  2002456   218772384  4.009593e+09
# 910   SZ002460   59039851.0  2.553695e+09  2002460    59038751  2.553649e+09
# 1236  SZ002798    3673927.0  8.383923e+07  2002798     3673627  8.383249e+07
# 1364  SZ002937    5058576.0  7.852348e+07  2002937     5054576  7.846181e+07
# 1415  SZ300017   86463136.0  7.248101e+08  2300017    86462536  7.248052e+08
# 1494  SZ300098   66305403.0  3.530078e+08  2300098    66285403  3.529026e+08
# 1827  SZ300438   15452528.0  4.389533e+08  2300438    15450528  4.388980e+08
# 1869  SZ300480   12561599.0  2.469841e+08  2300480    12556599  2.468911e+08
# 2020-01-23
# trade finished
# 0:12:17.712658
# 0:00:17.862023
# 20200203 unzip finished
# /home/work516/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:282: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /home/work516/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:283: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /home/work516/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:284: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
# 2020-02-03
# trade finished
# 0:05:18.340310
# 0:00:43.304407
# 20200204 unzip finished
# 2020-02-04
# trade finished
# 0:13:51.951551
# 0:00:43.585129
# 20200205 unzip finished
# 2020-02-05
# trade finished
# 0:14:06.325212
# 0:00:52.138396
# 20200206 unzip finished
# 2020-02-06
# trade finished
# 0:14:33.066820
# 0:00:45.052206
# 20200207 unzip finished
# 2020-02-07
# trade finished
# 0:14:53.496839
# 0:00:42.644696
# 20200210 unzip finished
# 2020-02-10
# trade finished
# 0:14:08.960072
# 0:00:41.812703
# 20200211 unzip finished
# 2020-02-11
# trade finished
# 0:13:17.920456
# 0:00:39.630340
# 20200212 unzip finished
# 2020-02-12
# trade finished
# 0:13:21.744411
# 0:00:41.793861
# 20200213 unzip finished
# 2020-02-13
# trade finished
# 0:13:56.573032
# 0:00:40.231200
# 20200214 unzip finished
# 2020-02-14
# trade finished
# 0:13:19.989219
# 0:00:42.834794
# 20200217 unzip finished
# 2020-02-17
# trade finished
# 0:13:52.989676
# 0:00:47.195667
# 20200218 unzip finished
# 2020-02-18
# trade finished
# 0:15:37.447598
# 0:00:54.307577
# 20200219 unzip finished
# 2020-02-19
# trade finished
# 0:16:11.042454
# 0:00:51.505651
# 20200220 unzip finished
# 2020-02-20
# trade finished
# 0:15:47.779892
# 0:00:52.850768
# 20200221 unzip finished
# 2020-02-21
# trade finished
# 0:17:00.171173
# 0:00:50.736627
# 20200224 unzip finished
# 2020-02-24
# trade finished
# 0:17:11.274859
# 0:00:59.146984
# 20200225 unzip finished
# 2020-02-25
# trade finished
# 0:20:13.607294
# 0:00:58.214066
# 20200226 unzip finished
# 2020-02-26
# trade finished
# 0:18:19.564233
# 0:00:46.972015
# 20200227 unzip finished
# 2020-02-27
# trade finished
# 0:15:42.664494
# 0:00:51.341402
# 20200228 unzip finished
# 2020-02-28
# trade finished
# 0:17:21.347720
# 0:00:46.235777
# 20200302 unzip finished
# 2020-03-02
# trade finished
# 0:14:57.637057
# 0:00:52.007765
# 20200303 unzip finished
# 2020-03-03
# trade finished
# 0:16:27.167408
# 0:00:47.418435
# 20200304 unzip finished
# 2020-03-04
# trade finished
# 0:15:07.038169
# 0:00:47.251483
# 20200305 unzip finished
# 2020-03-05
# trade finished
# 0:15:54.345194
# 0:00:49.253898
# 20200306 unzip finished
# 2020-03-06
# trade finished
# 0:14:55.441026
# 0:00:48.237982
# 20200309 unzip finished
# 2020-03-09
# trade finished
# 0:16:26.021653
# 0:00:50.827959
# 20200310 unzip finished
# 2020-03-10
# trade finished
# 0:17:11.567470
# 0:01:02.705712
# 20200311 unzip finished
# 2020-03-11
# trade finished
# 0:16:09.215273
# 0:01:16.169902
# 20200312 unzip finished
# 2020-03-12
# trade finished
# 0:14:21.896612
# 0:04:56.703078
# 20200313 unzip finished
# {2000002,
#  2000004,
#  2000005,
#  2000006,
#  2000007,
#  2000008,
#  2000009,
#  2000010,
#  2000011,
#  2000012,
#  2000014,
#  2000016,
#  2000017,
#  2000019,
#  2000020,
#  2000021,
#  2000023,
#  2000025,
#  2000026,
#  2000027,
#  2000028,
#  2000030,
#  2000031,
#  2000032,
#  2000034,
#  2000035,
#  2000036,
#  2000037,
#  2000038,
#  2000039,
#  2000040,
#  2000042,
#  2000045,
#  2000046,
#  2000048,
#  2000049,
#  2000050,
#  2000055,
#  2000056,
#  2000058,
#  2000059,
#  2000060,
#  2000061,
#  2000062,
#  2000063,
#  2000065,
#  2000066,
#  2000068,
#  2000069,
#  2000070,
#  2000078,
#  2000088,
#  2000089,
#  2000090,
#  2000096,
#  2000099,
#  2000100,
#  2000150,
#  2000151,
#  2000153,
#  2000155,
#  2000156,
#  2000157,
#  2000158,
#  2000159,
#  2000166,
#  2000301,
#  2000333,
#  2000338,
#  2000400,
#  2000401,
#  2000402,
#  2000403,
#  2000404,
#  2000407,
#  2000408,
#  2000409,
#  2000410,
#  2000411,
#  2000413,
#  2000415,
#  2000416,
#  2000417,
#  2000419,
#  2000420,
#  2000421,
#  2000422,
#  2000423,
#  2000425,
#  2000426,
#  2000428,
#  2000429,
#  2000430,
#  2000488,
#  2000498,
#  2000501,
#  2000503,
#  2000504,
#  2000505,
#  2000506,
#  2000507,
#  2000509,
#  2000510,
#  2000513,
#  2000514,
#  2000516,
#  2000517,
#  2000518,
#  2000519,
#  2000520,
#  2000521,
#  2000523,
#  2000524,
#  2000525,
#  2000526,
#  2000528,
#  2000529,
#  2000530,
#  2000531,
#  2000532,
#  2000533,
#  2000534,
#  2000536,
#  2000537,
#  2000538,
#  2000539,
#  2000540,
#  2000541,
#  2000543,
#  2000544,
#  2000545,
#  2000546,
#  2000547,
#  2000548,
#  2000550,
#  2000551,
#  2000552,
#  2000553,
#  2000554,
#  2000555,
#  2000557,
#  2000558,
#  2000559,
#  2000560,
#  2000561,
#  2000563,
#  2000564,
#  2000565,
#  2000566,
#  2000567,
#  2000568,
#  2000570,
#  2000571,
#  2000572,
#  2000573,
#  2000576,
#  2000581,
#  2000582,
#  2000584,
#  2000585,
#  2000586,
#  2000587,
#  2000589,
#  2000590,
#  2000591,
#  2000592,
#  2000593,
#  2000595,
#  2000596,
#  2000597,
#  2000598,
#  2000599,
#  2000600,
#  2000601,
#  2000603,
#  2000605,
#  2000606,
#  2000607,
#  2000608,
#  2000609,
#  2000610,
#  2000611,
#  2000612,
#  2000613,
#  2000615,
#  2000616,
#  2000617,
#  2000619,
#  2000620,
#  2000622,
#  2000623,
#  2000625,
#  2000626,
#  2000627,
#  2000628,
#  2000629,
#  2000630,
#  2000631,
#  2000632,
#  2000633,
#  2000635,
#  2000636,
#  2000637,
#  2000638,
#  2000639,
#  2000650,
#  2000651,
#  2000652,
#  2000655,
#  2000656,
#  2000657,
#  2000659,
#  2000661,
#  2000662,
#  2000663,
#  2000665,
#  2000666,
#  2000667,
#  2000668,
#  2000669,
#  2000670,
#  2000671,
#  2000672,
#  2000673,
#  2000676,
#  2000677,
#  2000678,
#  2000679,
#  2000680,
#  2000681,
#  2000682,
#  2000683,
#  2000685,
#  2000686,
#  2000687,
#  2000688,
#  2000690,
#  2000691,
#  2000692,
#  2000695,
#  2000697,
#  2000698,
#  2000700,
#  2000701,
#  2000702,
#  2000703,
#  2000705,
#  2000707,
#  2000708,
#  2000709,
#  2000710,
#  2000711,
#  2000712,
#  2000713,
#  2000715,
#  2000716,
#  2000717,
#  2000718,
#  2000719,
#  2000720,
#  2000721,
#  2000722,
#  2000723,
#  2000725,
#  2000726,
#  2000727,
#  2000728,
#  2000729,
#  2000731,
#  2000732,
#  2000733,
#  2000735,
#  2000736,
#  2000737,
#  2000738,
#  2000739,
#  2000750,
#  2000751,
#  2000752,
#  2000753,
#  2000755,
#  2000756,
#  2000757,
#  2000758,
#  2000759,
#  2000760,
#  2000761,
#  2000762,
#  2000766,
#  2000767,
#  2000768,
#  2000776,
#  2000777,
#  2000778,
#  2000779,
#  2000780,
#  2000782,
#  2000783,
#  2000785,
#  2000786,
#  2000788,
#  2000789,
#  2000790,
#  2000791,
#  2000792,
#  2000793,
#  2000795,
#  2000796,
#  2000797,
#  2000798,
#  2000799,
#  2000800,
#  2000801,
#  2000802,
#  2000803,
#  2000806,
#  2000807,
#  2000809,
#  2000810,
#  2000811,
#  2000812,
#  2000813,
#  2000815,
#  2000816,
#  2000818,
#  2000819,
#  2000820,
#  2000821,
#  2000822,
#  2000823,
#  2000825,
#  2000826,
#  2000828,
#  2000829,
#  2000830,
#  2000831,
#  2000833,
#  2000835,
#  2000836,
#  2000837,
#  2000838,
#  2000839,
#  2000848,
#  2000850,
#  2000851,
#  2000852,
#  2000856,
#  2000858,
#  2000859,
#  2000860,
#  2000861,
#  2000862,
#  2000863,
#  2000868,
#  2000869,
#  2000875,
#  2000876,
#  2000877,
#  2000878,
#  2000880,
#  2000881,
#  2000882,
#  2000883,
#  2000885,
#  2000886,
#  2000887,
#  2000888,
#  2000889,
#  2000890,
#  2000892,
#  2000893,
#  2000895,
#  2000897,
#  2000898,
#  2000899,
#  2000900,
#  2000901,
#  2000902,
#  2000903,
#  2000905,
#  2000906,
#  2000908,
#  2000909,
#  2000910,
#  2000911,
#  2000912,
#  2000913,
#  2000915,
#  2000917,
#  2000918,
#  2000919,
#  2000920,
#  2000921,
#  2000922,
#  2000923,
#  2000925,
#  2000926,
#  2000927,
#  2000928,
#  2000929,
#  2000930,
#  2000931,
#  2000932,
#  2000933,
#  2000935,
#  2000936,
#  2000937,
#  2000938,
#  2000948,
#  2000949,
#  2000950,
#  2000951,
#  2000952,
#  2000953,
#  2000955,
#  2000957,
#  2000958,
#  2000959,
#  2000960,
#  2000961,
#  2000962,
#  2000963,
#  2000965,
#  2000966,
#  2000967,
#  2000968,
#  2000969,
#  2000970,
#  2000971,
#  2000972,
#  2000973,
#  2000975,
#  2000976,
#  2000978,
#  2000980,
#  2000981,
#  2000982,
#  2000983,
#  2000985,
#  2000987,
#  2000988,
#  2000989,
#  2000990,
#  2000993,
#  2000996,
#  2000997,
#  2000998,
#  2000999,
#  2001696,
#  2001872,
#  2001896,
#  2001914,
#  2001965,
#  2001979,
#  2002001,
#  2002002,
#  2002003,
#  2002004,
#  2002005,
#  2002006,
#  2002007,
#  2002008,
#  2002009,
#  2002010,
#  2002011,
#  2002012,
#  2002013,
#  2002014,
#  2002015,
#  2002016,
#  2002017,
#  2002019,
#  2002020,
#  2002021,
#  2002022,
#  2002023,
#  2002024,
#  2002025,
#  2002026,
#  2002027,
#  2002028,
#  2002029,
#  2002030,
#  2002031,
#  2002032,
#  2002033,
#  2002034,
#  2002035,
#  2002036,
#  2002037,
#  2002038,
#  2002039,
#  2002040,
#  2002041,
#  2002042,
#  2002043,
#  2002044,
#  2002045,
#  2002046,
#  2002047,
#  2002048,
#  2002049,
#  2002050,
#  2002051,
#  2002052,
#  2002053,
#  2002054,
#  2002055,
#  2002056,
#  2002057,
#  2002058,
#  2002059,
#  2002060,
#  2002061,
#  2002062,
#  2002063,
#  2002064,
#  2002065,
#  2002066,
#  2002067,
#  2002068,
#  2002069,
#  2002071,
#  2002072,
#  2002073,
#  2002074,
#  2002075,
#  2002076,
#  2002077,
#  2002078,
#  2002079,
#  2002080,
#  2002081,
#  2002082,
#  2002083,
#  2002084,
#  2002085,
#  2002086,
#  2002087,
#  2002088,
#  2002089,
#  2002090,
#  2002091,
#  2002092,
#  2002093,
#  2002094,
#  2002095,
#  2002096,
#  2002097,
#  2002098,
#  2002099,
#  2002100,
#  2002101,
#  2002102,
#  2002103,
#  2002104,
#  2002105,
#  2002106,
#  2002107,
#  2002108,
#  2002109,
#  2002110,
#  2002111,
#  2002112,
#  2002113,
#  2002114,
#  2002115,
#  2002116,
#  2002117,
#  2002118,
#  2002119,
#  2002120,
#  2002121,
#  2002122,
#  2002123,
#  2002124,
#  2002125,
#  2002126,
#  2002127,
#  2002128,
#  2002129,
#  2002130,
#  2002131,
#  2002132,
#  2002133,
#  2002134,
#  2002135,
#  2002136,
#  2002137,
#  2002138,
#  2002139,
#  2002140,
#  2002141,
#  2002142,
#  2002144,
#  2002145,
#  2002146,
#  2002147,
#  2002148,
#  2002149,
#  2002150,
#  2002151,
#  2002152,
#  2002153,
#  2002154,
#  2002155,
#  2002156,
#  2002157,
#  2002158,
#  2002159,
#  2002160,
#  2002161,
#  2002162,
#  2002163,
#  2002164,
#  2002165,
#  2002166,
#  2002167,
#  2002168,
#  2002169,
#  2002170,
#  2002171,
#  2002172,
#  2002173,
#  2002174,
#  2002175,
#  2002176,
#  2002177,
#  2002178,
#  2002179,
#  2002180,
#  2002181,
#  2002182,
#  2002183,
#  2002184,
#  2002185,
#  2002186,
#  2002187,
#  2002188,
#  2002189,
#  2002190,
#  2002191,
#  2002192,
#  2002193,
#  2002194,
#  2002195,
#  2002196,
#  2002197,
#  2002198,
#  2002199,
#  2002200,
#  2002201,
#  2002202,
#  2002203,
#  2002204,
#  2002205,
#  2002206,
#  2002207,
#  2002208,
#  2002209,
#  2002210,
#  2002211,
#  2002212,
#  2002213,
#  2002214,
#  2002215,
#  2002216,
#  2002217,
#  2002218,
#  2002219,
#  2002220,
#  2002221,
#  2002222,
#  2002223,
#  2002224,
#  2002225,
#  2002226,
#  2002227,
#  2002228,
#  2002229,
#  2002230,
#  2002231,
#  2002232,
#  2002233,
#  2002234,
#  2002235,
#  2002236,
#  2002237,
#  2002238,
#  2002239,
#  2002240,
#  2002241,
#  2002242,
#  2002243,
#  2002244,
#  2002245,
#  2002246,
#  2002247,
#  2002248,
#  2002249,
#  2002250,
#  2002251,
#  2002252,
#  2002253,
#  2002254,
#  2002255,
#  2002256,
#  2002258,
#  2002259,
#  2002261,
#  2002262,
#  2002263,
#  2002264,
#  2002265,
#  2002266,
#  2002267,
#  2002268,
#  2002269,
#  2002270,
#  2002271,
#  2002272,
#  2002273,
#  2002274,
#  2002275,
#  2002276,
#  2002277,
#  2002278,
#  2002279,
#  2002280,
#  2002281,
#  2002282,
#  2002283,
#  2002284,
#  2002285,
#  2002286,
#  2002287,
#  2002288,
#  2002289,
#  2002290,
#  2002291,
#  2002292,
#  2002293,
#  2002294,
#  2002295,
#  2002296,
#  2002297,
#  2002298,
#  2002299,
#  2002300,
#  2002301,
#  2002302,
#  2002303,
#  2002304,
#  2002305,
#  2002306,
#  2002307,
#  2002308,
#  2002309,
#  2002310,
#  2002311,
#  2002312,
#  2002313,
#  2002314,
#  2002315,
#  2002316,
#  2002317,
#  2002318,
#  2002319,
#  2002320,
#  2002321,
#  2002322,
#  2002323,
#  2002324,
#  2002325,
#  2002326,
#  2002327,
#  2002328,
#  2002329,
#  2002330,
#  2002331,
#  2002332,
#  2002333,
#  2002334,
#  2002335,
#  2002336,
#  2002337,
#  2002338,
#  2002339,
#  2002340,
#  2002341,
#  2002342,
#  2002343,
#  2002344,
#  2002345,
#  2002346,
#  2002347,
#  2002348,
#  2002349,
#  2002350,
#  2002351,
#  2002352,
#  2002353,
#  2002354,
#  2002355,
#  2002356,
#  2002357,
#  2002358,
#  2002359,
#  2002360,
#  2002361,
#  2002362,
#  2002363,
#  2002364,
#  2002365,
#  2002366,
#  2002367,
#  2002368,
#  2002369,
#  2002370,
#  2002371,
#  2002372,
#  2002373,
#  2002374,
#  2002375,
#  2002376,
#  2002377,
#  2002378,
#  2002379,
#  2002380,
#  2002381,
#  2002382,
#  2002383,
#  2002384,
#  2002385,
#  2002386,
#  2002387,
#  2002388,
#  2002389,
#  2002390,
#  2002391,
#  2002392,
#  2002393,
#  2002394,
#  2002395,
#  2002396,
#  2002397,
#  2002398,
#  2002399,
#  2002400,
#  2002401,
#  2002402,
#  2002403,
#  2002404,
#  2002405,
#  2002406,
#  2002407,
#  2002408,
#  2002409,
#  2002410,
#  2002411,
#  2002412,
#  2002413,
#  2002414,
#  2002415,
#  2002416,
#  2002417,
#  2002418,
#  2002419,
#  2002420,
#  2002421,
#  2002422,
#  2002423,
#  2002424,
#  2002425,
#  2002426,
#  2002427,
#  2002428,
#  2002429,
#  2002430,
#  2002431,
#  2002432,
#  2002433,
#  2002434,
#  2002435,
#  2002436,
#  2002437,
#  2002438,
#  2002439,
#  2002440,
#  2002441,
#  2002442,
#  2002443,
#  2002444,
#  2002445,
#  2002446,
#  2002447,
#  2002448,
#  2002449,
#  2002451,
#  2002452,
#  2002453,
#  2002454,
#  2002455,
#  2002456,
#  2002457,
#  2002458,
#  2002459,
#  2002460,
#  2002461,
#  2002462,
#  2002463,
#  2002464,
#  2002465,
#  2002466,
#  2002467,
#  2002468,
#  2002469,
#  2002470,
#  2002471,
#  2002472,
#  2002473,
#  2002474,
#  2002475,
#  2002476,
#  2002478,
#  2002479,
#  2002480,
#  2002481,
#  2002482,
#  2002483,
#  2002484,
#  2002485,
#  2002486,
#  2002487,
#  2002488,
#  2002489,
#  2002490,
#  2002491,
#  2002492,
#  2002493,
#  2002494,
#  2002495,
#  2002496,
#  2002497,
#  2002498,
#  2002499,
#  2002500,
#  2002501,
#  2002502,
#  2002503,
#  2002504,
#  2002505,
#  2002506,
#  2002507,
#  2002508,
#  2002509,
#  2002510,
#  2002511,
#  2002512,
#  2002513,
#  2002514,
#  2002515,
#  2002516,
#  2002517,
#  2002518,
#  2002519,
#  2002520,
#  2002521,
#  2002522,
#  2002523,
#  2002524,
#  2002526,
#  2002527,
#  2002528,
#  2002529,
#  2002530,
#  2002531,
#  2002532,
#  2002533,
#  2002534,
#  2002535,
#  2002536,
#  2002537,
#  2002538,
#  2002539,
#  2002540,
#  2002541,
#  2002542,
#  2002543,
#  2002544,
#  2002545,
#  2002546,
#  2002547,
#  2002548,
#  2002549,
#  2002550,
#  2002551,
#  2002552,
#  2002553,
#  2002554,
#  ...}
#             ID  max_volume    max_amount     skey  cum_volume  cum_amount
# 1     SZ000002  73253061.0  2.122143e+09  2000002         NaN         NaN
# 2     SZ000004   4948058.0  1.863005e+08  2000004         NaN         NaN
# 3     SZ000005  13668719.0  3.943993e+07  2000005         NaN         NaN
# 4     SZ000006  16732683.0  7.799912e+07  2000006         NaN         NaN
# 5     SZ000007   6923153.0  5.704177e+07  2000007         NaN         NaN
# ...        ...         ...           ...      ...         ...         ...
# 2191  SZ300818   1447706.0  5.069249e+07  2300818         NaN         NaN
# 2192  SZ300819     28535.0  6.811304e+05  2300819         NaN         NaN
# 2193  SZ300820   1939456.0  2.378142e+08  2300820         NaN         NaN
# 2194  SZ300821    533212.0  5.828007e+06  2300821         NaN         NaN
# 2195  SZ300822     85644.0  2.900814e+06  2300822         NaN         NaN
#
# [2195 rows x 6 columns]
#             ID  max_volume    max_amount     skey  cum_volume  cum_amount
# 1     SZ000002  73253061.0  2.122143e+09  2000002         NaN         NaN
# 2     SZ000004   4948058.0  1.863005e+08  2000004         NaN         NaN
# 3     SZ000005  13668719.0  3.943993e+07  2000005         NaN         NaN
# 4     SZ000006  16732683.0  7.799912e+07  2000006         NaN         NaN
# 5     SZ000007   6923153.0  5.704177e+07  2000007         NaN         NaN
# ...        ...         ...           ...      ...         ...         ...
# 2191  SZ300818   1447706.0  5.069249e+07  2300818         NaN         NaN
# 2192  SZ300819     28535.0  6.811304e+05  2300819         NaN         NaN
# 2193  SZ300820   1939456.0  2.378142e+08  2300820         NaN         NaN
# 2194  SZ300821    533212.0  5.828007e+06  2300821         NaN         NaN
# 2195  SZ300822     85644.0  2.900814e+06  2300822         NaN         NaN
#
# [2195 rows x 6 columns]
# 2020-03-13
# trade finished
# 0:00:02.594564
# 0:00:00.272622
# 20200316 unzip finished
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-1-568ea0a42c6a> in <module>
#     254         df["SecurityID"] = int(os.path.basename(i).split('.')[0])
#     255         TradeLog += [df]
# --> 256     TradeLog = pd.concat(TradeLog).reset_index(drop=True)
#     257     TradeLog = TradeLog[TradeLog["ChannelNo"] != 4001]
#     258
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/reshape/concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     279         verify_integrity=verify_integrity,
#     280         copy=copy,
# --> 281         sort=sort,
#     282     )
#     283
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/reshape/concat.py in __init__(self, objs, axis, join, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     327
#     328         if len(objs) == 0:
# --> 329             raise ValueError("No objects to concatenate")
#     330
#     331         if keys is None:
#
# ValueError: No objects to concatenate

# %%
import pymongo
import pandas as pd
import pickle
import datetime
import time
import gzip
import lzma
import pytz


def DB(host, db_name, user, passwd):
    auth_db = db_name if user not in ('admin', 'root') else 'admin'
    uri = 'mongodb://%s:%s@%s/?authSource=%s' % (user, passwd, host, auth_db)
    return DBObj(uri, db_name=db_name)


class DBObj(object):
    def __init__(self, uri, symbol_column='skey', db_name='white_db'):
        self.db_name = db_name
        self.uri = uri
        self.client = pymongo.MongoClient(self.uri)
        self.db = self.client[self.db_name]
        self.chunk_size = 20000
        self.symbol_column = symbol_column
        self.date_column = 'date'

    def parse_uri(self, uri):
        # mongodb://user:password@example.com
        return uri.strip().replace('mongodb://', '').strip('/').replace(':', ' ').replace('@', ' ').split(' ')

    def drop_table(self, table_name):
        self.db.drop_collection(table_name)

    def rename_table(self, old_table, new_table):
        self.db[old_table].rename(new_table)

    def write(self, table_name, df):
        if len(df) == 0: return

        multi_date = False

        if self.date_column in df.columns:
            date = str(df.head(1)[self.date_column].iloc[0])
            multi_date = len(df[self.date_column].unique()) > 1
        else:
            raise Exception('DataFrame should contain date column')

        collection = self.db[table_name]
        collection.create_index([('date', pymongo.ASCENDING), ('symbol', pymongo.ASCENDING)], background=True)
        collection.create_index([('symbol', pymongo.ASCENDING), ('date', pymongo.ASCENDING)], background=True)

        if multi_date:
            for (date, symbol), sub_df in df.groupby([self.date_column, self.symbol_column]):
                date = str(date)
                symbol = int(symbol)
                collection.delete_many({'date': date, 'symbol': symbol})
                self.write_single(collection, date, symbol, sub_df)
        else:
            for symbol, sub_df in df.groupby([self.symbol_column]):
                collection.delete_many({'date': date, 'symbol': symbol})
                self.write_single(collection, date, symbol, sub_df)

    def write_single(self, collection, date, symbol, df):
        for start in range(0, len(df), self.chunk_size):
            end = min(start + self.chunk_size, len(df))
            df_seg = df[start:end]
            version = 1
            seg = {'ver': version, 'data': self.ser(df_seg, version), 'date': date, 'symbol': symbol, 'start': start}
            collection.insert_one(seg)

    def build_query(self, start_date=None, end_date=None, symbol=None):
        query = {}

        def parse_date(x):
            if type(x) == str:
                if len(x) != 8:
                    raise Exception("`date` must be YYYYMMDD format")
                return x
            elif type(x) == datetime.datetime or type(x) == datetime.date:
                return x.strftime("%Y%m%d")
            elif type(x) == int:
                return parse_date(str(x))
            else:
                raise Exception("invalid `date` type: " + str(type(x)))

        if start_date is not None or end_date is not None:
            query['date'] = {}
            if start_date is not None:
                query['date']['$gte'] = parse_date(start_date)
            if end_date is not None:
                query['date']['$lte'] = parse_date(end_date)

        def parse_symbol(x):
            if type(x) == int:
                return x
            else:
                return int(x)

        if symbol:
            if type(symbol) == list or type(symbol) == tuple:
                query['symbol'] = {'$in': [parse_symbol(x) for x in symbol]}
            else:
                query['symbol'] = parse_symbol(symbol)

        return query

    def delete(self, table_name, start_date=None, end_date=None, symbol=None):
        collection = self.db[table_name]

        query = self.build_query(start_date, end_date, symbol)
        if not query:
            print('cannot delete the whole table')
            return None

        collection.delete_many(query)

    def read(self, table_name, start_date=None, end_date=None, symbol=None):
        collection = self.db[table_name]

        query = self.build_query(start_date, end_date, symbol)
        if not query:
            print('cannot read the whole table')
            return None

        segs = []
        for x in collection.find(query):
            x['data'] = self.deser(x['data'], x['ver'])
            segs.append(x)
        segs.sort(key=lambda x: (x['symbol'], x['date'], x['start']))
        return pd.concat([x['data'] for x in segs], ignore_index=True) if segs else None

    def list_tables(self):
        return self.db.collection_names()

    def list_dates(self, table_name, start_date=None, end_date=None, symbol=None):
        collection = self.db[table_name]
        dates = set()
        if start_date is None:
            start_date = '00000000'
        if end_date is None:
            end_date = '99999999'
        for x in collection.find(self.build_query(start_date, end_date, symbol), {"date": 1, '_id': 0}):
            dates.add(x['date'])
        return sorted(list(dates))

    def ser(self, s, version):
        pickle_protocol = 4
        if version == 1:
            return gzip.compress(pickle.dumps(s, protocol=pickle_protocol), compresslevel=2)
        elif version == 2:
            return lzma.compress(pickle.dumps(s, protocol=pickle_protocol), preset=1)
        else:
            raise Exception('unknown version')

    def deser(self, s, version):
        def unpickle(s):
            return pickle.loads(s)

        if version == 1:
            return unpickle(gzip.decompress(s))
        elif version == 2:
            return unpickle(lzma.decompress(s))
        else:
            raise Exception('unknown version')


def patch_pandas_pickle():
    if pd.__version__ < '0.24':
        import sys
        from types import ModuleType
        from pandas.core.internals import BlockManager
        pkg_name = 'pandas.core.internals.managers'
        if pkg_name not in sys.modules:
            m = ModuleType(pkg_name)
            m.BlockManager = BlockManager
            sys.modules[pkg_name] = m
patch_pandas_pickle()


            
            
            
            
            
            
            
            
import pandas as pd
import random
import numpy as np
import glob
import os
import pickle
import datetime
import time
pd.set_option("max_columns", 200)

startTm = datetime.datetime.now()
readPath = '/home/work516/day_stock/***'
dataPathLs = np.array(glob.glob(readPath))
dataPathLs = dataPathLs[[np.array([os.path.basename(i).split('.')[0][:2] == 'SZ' for i in dataPathLs])]]
db = pd.DataFrame()
for p in dataPathLs:
    dayData = pd.read_csv(p, compression='gzip')
    db = pd.concat([db, dayData])
print(datetime.datetime.now() - startTm)

year = "2020"
startDate = '20200313'
endDate = '20200529'
readPath = '/mnt/usb/data/' + year + '/***/***'
dataPathLs = np.array(glob.glob(readPath))
dateLs = np.array([os.path.basename(i) for i in dataPathLs])
dataPathLs = dataPathLs[(dateLs >= startDate) & (dateLs <= endDate)]

for data in dataPathLs:
    
    if len(np.array(glob.glob(data + '/SZ/***'))) == 0:
        if int(os.path.basename(data)) not in date_list["Date"].values:
            continue
        else:
            print(os.path.basename(data) + " less data!!!!!!!!!!!!!!!!!")
            less.append(data)
            continue
    startTm = datetime.datetime.now()
    date = os.path.basename(data)
    rar_path = data + '/SZ/tick.7z'
    path = '/mnt/e/unzip_data/2020/SZ'
    path1 = path + '/' + date
    un_path = path1
    cmd = '7za x {} -o{}'.format(rar_path, un_path)
    os.system(cmd)
    print(datetime.datetime.now() - startTm)
    print(date + ' unzip finished')
    
    
    startTm = datetime.datetime.now()
    
    readPath = path1 + '/tick/***'
    dataPathLs = np.array(glob.glob(readPath))
    dateLs = np.array([int(os.path.basename(i).split('.')[0]) for i in dataPathLs])
    dataPathLs = dataPathLs[(dateLs < 4000) | ((dateLs > 300000) & (dateLs < 310000))]
    TradeLog = []
    ll = []
    
    for i in dataPathLs:
        try:
            df = pd.read_csv(i)
        except:
            print("empty data")
            print(i)
            ll.append(int(os.path.basename(i).split('.')[0]))
            continue
        df["SecurityID"] = int(os.path.basename(i).split('.')[0])
        TradeLog += [df]
    TradeLog = pd.concat(TradeLog).reset_index(drop=True)
    TradeLog = TradeLog[TradeLog["ChannelNo"] != 4001]
    
    TradeLog["date"] = TradeLog["TransactTime"].iloc[0]//1000000000
    TradeLog = TradeLog.rename(columns={"Qty":"trade_qty", "Price":"trade_price", "ExecType":"trade_type"})
    TradeLog["trade_money"] = TradeLog["trade_price"] * TradeLog["trade_qty"]
    TradeLog["trade_flag"] = 0
    TradeLog["skey"] = TradeLog["SecurityID"] + 2000000
    TradeLog["clockAtArrival"] = TradeLog["TransactTime"].astype(str).apply(lambda x: np.int64(datetime.datetime.strptime(x, '%Y%m%d%H%M%S%f').timestamp()*1e6))
    TradeLog['datetime'] = TradeLog["clockAtArrival"].apply(lambda x: datetime.datetime.fromtimestamp(x/1e6))
    TradeLog["time"] = (TradeLog['TransactTime'] - int(TradeLog['TransactTime'].iloc[0]//1000000000*1000000000)).astype(np.int64)*1000
    TradeLog["trade_type"] = np.where(TradeLog["trade_type"] == 'F', 1, TradeLog["trade_type"])
    for col in ["skey", "date", "ApplSeqNum", "BidApplSeqNum", "OfferApplSeqNum", "trade_qty", "trade_type", "trade_flag"]:
        TradeLog[col] = TradeLog[col].astype('int32')
#     for cols in ["trade_money", "trade_price"]:
#         display(cols)
#         display(TradeLog[cols].astype(str).apply(lambda x: len(str(x.split('.')[1]))).unique())
#         TradeLog[cols] = TradeLog[cols].round(2)
#         display(TradeLog[cols].astype(str).apply(lambda x: len(str(x.split('.')[1]))).unique())
    for cols in ["trade_money"]:
        TradeLog[cols] = TradeLog[cols].round(2)
    
    da_te = str(TradeLog["date"].iloc[0]) 
    da_te = da_te[:4] + '-' + da_te[4:6] + '-' + da_te[6:8]
    db1 = db[db["date"] == da_te]
    sl = (db1["ID"].str[2:].astype(int) + 2000000).unique()
    db1["max_volume"] = db1.groupby("ID")["d_volume"].transform("max")
    db1["max_amount"] = db1.groupby("ID")["d_amount"].transform("max")
    t1 = db1.groupby("ID")["max_volume", "max_amount"].first().reset_index()
    del db1
    t1["skey"] = t1["ID"].str[2:].astype(int) + 2000000
    trade1 = TradeLog[TradeLog["trade_type"] == 1].groupby("skey")["trade_qty"].sum().reset_index()
    trade1.columns=["skey", "cum_volume"]
    trade2 = TradeLog[TradeLog["trade_type"] == 1].groupby("skey")["trade_money"].sum().reset_index()
    trade2.columns=["skey", "cum_amount"]
    t2 = pd.merge(trade1, trade2, on="skey")
    re = pd.merge(t1, t2, on="skey", how="outer")
    try:
        assert(t1.shape[0] == t2.shape[0])
        assert(re[re["cum_volume"] != re["max_volume"]].shape[0] == 0)
        assert(re[re["cum_amount"].round(2) != re["max_amount"]].shape[0] == 0)
    except:
        display(set(t1["skey"]) - set(t2["skey"]))
        display(re[re["cum_volume"] != re["max_volume"]])
        display(re[re["cum_amount"].round(2) != re["max_amount"]])
    del t1
    del t2
    del re
 
    TradeLog = TradeLog[["skey", "date", "time", "clockAtArrival", "datetime", "ApplSeqNum", "trade_type", "trade_flag",
                                                 "trade_price", "trade_qty", "BidApplSeqNum", "OfferApplSeqNum"]]
    print(da_te)
    print("trade finished")


    database_name = 'com_md_eq_cn'
    user = "zhenyuy"
    password = "bnONBrzSMGoE"

    db1 = DB("192.168.10.223", database_name, user, password)
    db1.write('md_trade', TradeLog)    
    
    del TradeLog

    print(datetime.datetime.now() - startTm)
# Out:
# /home/work516/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:201: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
# 0:05:32.778531
# 0:00:39.875453
# 20200313 unzip finished
# /home/work516/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:282: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /home/work516/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:283: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /home/work516/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:284: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
# 2020-03-13
# trade finished
# 0:14:46.161557
# 0:00:52.752605
# 20200316 unzip finished
# 2020-03-16
# trade finished
# 0:16:19.287593
# 0:00:47.076649
# 20200317 unzip finished
# 2020-03-17
# trade finished
# 0:13:47.876184
# 0:00:45.702508
# 20200318 unzip finished
# 2020-03-18
# trade finished
# 0:15:28.674127
# 0:00:50.527394
# 20200319 unzip finished
# 2020-03-19
# trade finished
# 0:15:59.824166
# 0:00:43.677323
# 20200320 unzip finished
# 2020-03-20
# trade finished
# 0:12:29.637345
# 0:00:42.988152
# 20200323 unzip finished

# %%
import pymongo
import pandas as pd
import pickle
import datetime
import time
import gzip
import lzma
import pytz


def DB(host, db_name, user, passwd):
    auth_db = db_name if user not in ('admin', 'root') else 'admin'
    uri = 'mongodb://%s:%s@%s/?authSource=%s' % (user, passwd, host, auth_db)
    return DBObj(uri, db_name=db_name)


class DBObj(object):
    def __init__(self, uri, symbol_column='skey', db_name='white_db'):
        self.db_name = db_name
        self.uri = uri
        self.client = pymongo.MongoClient(self.uri)
        self.db = self.client[self.db_name]
        self.chunk_size = 20000
        self.symbol_column = symbol_column
        self.date_column = 'date'

    def parse_uri(self, uri):
        # mongodb://user:password@example.com
        return uri.strip().replace('mongodb://', '').strip('/').replace(':', ' ').replace('@', ' ').split(' ')

    def drop_table(self, table_name):
        self.db.drop_collection(table_name)

    def rename_table(self, old_table, new_table):
        self.db[old_table].rename(new_table)

    def write(self, table_name, df):
        if len(df) == 0: return

        multi_date = False

        if self.date_column in df.columns:
            date = str(df.head(1)[self.date_column].iloc[0])
            multi_date = len(df[self.date_column].unique()) > 1
        else:
            raise Exception('DataFrame should contain date column')

        collection = self.db[table_name]
        collection.create_index([('date', pymongo.ASCENDING), ('symbol', pymongo.ASCENDING)], background=True)
        collection.create_index([('symbol', pymongo.ASCENDING), ('date', pymongo.ASCENDING)], background=True)

        if multi_date:
            for (date, symbol), sub_df in df.groupby([self.date_column, self.symbol_column]):
                date = str(date)
                symbol = int(symbol)
                collection.delete_many({'date': date, 'symbol': symbol})
                self.write_single(collection, date, symbol, sub_df)
        else:
            for symbol, sub_df in df.groupby([self.symbol_column]):
                collection.delete_many({'date': date, 'symbol': symbol})
                self.write_single(collection, date, symbol, sub_df)

    def write_single(self, collection, date, symbol, df):
        for start in range(0, len(df), self.chunk_size):
            end = min(start + self.chunk_size, len(df))
            df_seg = df[start:end]
            version = 1
            seg = {'ver': version, 'data': self.ser(df_seg, version), 'date': date, 'symbol': symbol, 'start': start}
            collection.insert_one(seg)

    def build_query(self, start_date=None, end_date=None, symbol=None):
        query = {}

        def parse_date(x):
            if type(x) == str:
                if len(x) != 8:
                    raise Exception("`date` must be YYYYMMDD format")
                return x
            elif type(x) == datetime.datetime or type(x) == datetime.date:
                return x.strftime("%Y%m%d")
            elif type(x) == int:
                return parse_date(str(x))
            else:
                raise Exception("invalid `date` type: " + str(type(x)))

        if start_date is not None or end_date is not None:
            query['date'] = {}
            if start_date is not None:
                query['date']['$gte'] = parse_date(start_date)
            if end_date is not None:
                query['date']['$lte'] = parse_date(end_date)

        def parse_symbol(x):
            if type(x) == int:
                return x
            else:
                return int(x)

        if symbol:
            if type(symbol) == list or type(symbol) == tuple:
                query['symbol'] = {'$in': [parse_symbol(x) for x in symbol]}
            else:
                query['symbol'] = parse_symbol(symbol)

        return query

    def delete(self, table_name, start_date=None, end_date=None, symbol=None):
        collection = self.db[table_name]

        query = self.build_query(start_date, end_date, symbol)
        if not query:
            print('cannot delete the whole table')
            return None

        collection.delete_many(query)

    def read(self, table_name, start_date=None, end_date=None, symbol=None):
        collection = self.db[table_name]

        query = self.build_query(start_date, end_date, symbol)
        if not query:
            print('cannot read the whole table')
            return None

        segs = []
        for x in collection.find(query):
            x['data'] = self.deser(x['data'], x['ver'])
            segs.append(x)
        segs.sort(key=lambda x: (x['symbol'], x['date'], x['start']))
        return pd.concat([x['data'] for x in segs], ignore_index=True) if segs else None

    def list_tables(self):
        return self.db.collection_names()

    def list_dates(self, table_name, start_date=None, end_date=None, symbol=None):
        collection = self.db[table_name]
        dates = set()
        if start_date is None:
            start_date = '00000000'
        if end_date is None:
            end_date = '99999999'
        for x in collection.find(self.build_query(start_date, end_date, symbol), {"date": 1, '_id': 0}):
            dates.add(x['date'])
        return sorted(list(dates))

    def ser(self, s, version):
        pickle_protocol = 4
        if version == 1:
            return gzip.compress(pickle.dumps(s, protocol=pickle_protocol), compresslevel=2)
        elif version == 2:
            return lzma.compress(pickle.dumps(s, protocol=pickle_protocol), preset=1)
        else:
            raise Exception('unknown version')

    def deser(self, s, version):
        def unpickle(s):
            return pickle.loads(s)

        if version == 1:
            return unpickle(gzip.decompress(s))
        elif version == 2:
            return unpickle(lzma.decompress(s))
        else:
            raise Exception('unknown version')


def patch_pandas_pickle():
    if pd.__version__ < '0.24':
        import sys
        from types import ModuleType
        from pandas.core.internals import BlockManager
        pkg_name = 'pandas.core.internals.managers'
        if pkg_name not in sys.modules:
            m = ModuleType(pkg_name)
            m.BlockManager = BlockManager
            sys.modules[pkg_name] = m
patch_pandas_pickle()


            
            
            
            
            
            
            
            
import pandas as pd
import random
import numpy as np
import glob
import os
import pickle
import datetime
import time
pd.set_option("max_columns", 200)

startTm = datetime.datetime.now()
readPath = '/home/work516/day_stock/***'
dataPathLs = np.array(glob.glob(readPath))
dataPathLs = dataPathLs[[np.array([os.path.basename(i).split('.')[0][:2] == 'SZ' for i in dataPathLs])]]
db = pd.DataFrame()
for p in dataPathLs:
    dayData = pd.read_csv(p, compression='gzip')
    db = pd.concat([db, dayData])
print(datetime.datetime.now() - startTm)

year = "2020"
startDate = '20200323'
endDate = '20200529'
readPath = '/mnt/usb/data/' + year + '/***/***'
dataPathLs = np.array(glob.glob(readPath))
dateLs = np.array([os.path.basename(i) for i in dataPathLs])
dataPathLs = dataPathLs[(dateLs >= startDate) & (dateLs <= endDate)]

for data in dataPathLs:
    
    if len(np.array(glob.glob(data + '/SZ/***'))) == 0:
        if int(os.path.basename(data)) not in date_list["Date"].values:
            continue
        else:
            print(os.path.basename(data) + " less data!!!!!!!!!!!!!!!!!")
            less.append(data)
            continue
    startTm = datetime.datetime.now()
    date = os.path.basename(data)
    rar_path = data + '/SZ/tick.7z'
    path = '/mnt/e/unzip_data/2020/SZ'
    path1 = path + '/' + date
    un_path = path1
    cmd = '7za x {} -o{}'.format(rar_path, un_path)
    os.system(cmd)
    print(datetime.datetime.now() - startTm)
    print(date + ' unzip finished')
    
    
    startTm = datetime.datetime.now()
    
    readPath = path1 + '/tick/***'
    dataPathLs = np.array(glob.glob(readPath))
    dateLs = np.array([int(os.path.basename(i).split('.')[0]) for i in dataPathLs])
    dataPathLs = dataPathLs[(dateLs < 4000) | ((dateLs > 300000) & (dateLs < 310000))]
    TradeLog = []
    ll = []
    
    for i in dataPathLs:
        try:
            df = pd.read_csv(i)
        except:
            print("empty data")
            print(i)
            ll.append(int(os.path.basename(i).split('.')[0]))
            continue
        df["SecurityID"] = int(os.path.basename(i).split('.')[0])
        TradeLog += [df]
    TradeLog = pd.concat(TradeLog).reset_index(drop=True)
    TradeLog = TradeLog[TradeLog["ChannelNo"] != 4001]
    
    TradeLog["date"] = TradeLog["TransactTime"].iloc[0]//1000000000
    TradeLog = TradeLog.rename(columns={"Qty":"trade_qty", "Price":"trade_price", "ExecType":"trade_type"})
    TradeLog["trade_money"] = TradeLog["trade_price"] * TradeLog["trade_qty"]
    TradeLog["trade_flag"] = 0
    TradeLog["skey"] = TradeLog["SecurityID"] + 2000000
    TradeLog["clockAtArrival"] = TradeLog["TransactTime"].astype(str).apply(lambda x: np.int64(datetime.datetime.strptime(x, '%Y%m%d%H%M%S%f').timestamp()*1e6))
    TradeLog['datetime'] = TradeLog["clockAtArrival"].apply(lambda x: datetime.datetime.fromtimestamp(x/1e6))
    TradeLog["time"] = (TradeLog['TransactTime'] - int(TradeLog['TransactTime'].iloc[0]//1000000000*1000000000)).astype(np.int64)*1000
    TradeLog["trade_type"] = np.where(TradeLog["trade_type"] == 'F', 1, TradeLog["trade_type"])
    for col in ["skey", "date", "ApplSeqNum", "BidApplSeqNum", "OfferApplSeqNum", "trade_qty", "trade_type", "trade_flag"]:
        TradeLog[col] = TradeLog[col].astype('int32')
#     for cols in ["trade_money", "trade_price"]:
#         display(cols)
#         display(TradeLog[cols].astype(str).apply(lambda x: len(str(x.split('.')[1]))).unique())
#         TradeLog[cols] = TradeLog[cols].round(2)
#         display(TradeLog[cols].astype(str).apply(lambda x: len(str(x.split('.')[1]))).unique())
    for cols in ["trade_money"]:
        TradeLog[cols] = TradeLog[cols].round(2)
    
    da_te = str(TradeLog["date"].iloc[0]) 
    da_te = da_te[:4] + '-' + da_te[4:6] + '-' + da_te[6:8]
    db1 = db[db["date"] == da_te]
    sl = (db1["ID"].str[2:].astype(int) + 2000000).unique()
    db1["max_volume"] = db1.groupby("ID")["d_volume"].transform("max")
    db1["max_amount"] = db1.groupby("ID")["d_amount"].transform("max")
    t1 = db1.groupby("ID")["max_volume", "max_amount"].first().reset_index()
    del db1
    t1["skey"] = t1["ID"].str[2:].astype(int) + 2000000
    trade1 = TradeLog[TradeLog["trade_type"] == 1].groupby("skey")["trade_qty"].sum().reset_index()
    trade1.columns=["skey", "cum_volume"]
    trade2 = TradeLog[TradeLog["trade_type"] == 1].groupby("skey")["trade_money"].sum().reset_index()
    trade2.columns=["skey", "cum_amount"]
    t2 = pd.merge(trade1, trade2, on="skey")
    re = pd.merge(t1, t2, on="skey", how="outer")
    try:
        assert(t1.shape[0] == t2.shape[0])
        assert(re[re["cum_volume"] != re["max_volume"]].shape[0] == 0)
        assert(re[re["cum_amount"].round(2) != re["max_amount"]].shape[0] == 0)
    except:
        display(set(t1["skey"]) - set(t2["skey"]))
        display(re[re["cum_volume"] != re["max_volume"]])
        display(re[re["cum_amount"].round(2) != re["max_amount"]])
    del t1
    del t2
    del re
 
    TradeLog = TradeLog[["skey", "date", "time", "clockAtArrival", "datetime", "ApplSeqNum", "trade_type", "trade_flag",
                                                 "trade_price", "trade_qty", "BidApplSeqNum", "OfferApplSeqNum"]]
    print(da_te)
    print("trade finished")


    database_name = 'com_md_eq_cn'
    user = "zhenyuy"
    password = "bnONBrzSMGoE"

    db1 = DB("192.168.10.223", database_name, user, password)
    db1.write('md_trade', TradeLog)    
    
    del TradeLog

    print(datetime.datetime.now() - startTm)
# Out:
# /home/work516/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:201: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
# 0:05:33.504464
# 0:00:00.429773
# 20200323 unzip finished
# /home/work516/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:282: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /home/work516/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:283: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /home/work516/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:284: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
# 2020-03-23
# trade finished
# 0:13:43.439359
# 0:00:00.553192
# 20200324 unzip finished
# 2020-03-24
# trade finished
# 0:13:35.726998
# 0:00:41.898963
# 20200325 unzip finished
# 2020-03-25
# trade finished
# 0:11:35.263058
# 0:00:38.002841
# 20200326 unzip finished
# 2020-03-26
# trade finished
# 0:10:47.952231
# 0:00:35.833855
# 20200327 unzip finished
# set()
#             ID  max_volume    max_amount     skey  cum_volume    cum_amount
# 1646  SZ300252  13634647.0  1.505004e+08  2300252    13633647  1.504896e+08
# 2194  SZ300821  43161516.0  5.509852e+08  2300821    43156916  5.509276e+08
#             ID  max_volume    max_amount     skey  cum_volume    cum_amount
# 1646  SZ300252  13634647.0  1.505004e+08  2300252    13633647  1.504896e+08
# 2194  SZ300821  43161516.0  5.509852e+08  2300821    43156916  5.509276e+08
# 2020-03-27
# trade finished
# 0:10:54.038944
# 0:00:39.453107
# 20200330 unzip finished
# /home/work516/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:282: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /home/work516/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:283: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /home/work516/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:284: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
# 2020-03-30
# trade finished
# 0:11:17.995843
# 0:00:35.544870
# 20200331 unzip finished
# 2020-03-31
# trade finished
# 0:10:31.901580
# 0:00:35.956553
# 20200401 unzip finished
# 2020-04-01
# trade finished
# 0:10:41.891199
# 0:00:34.669028
# 20200402 unzip finished
# 2020-04-02
# trade finished
# 0:10:39.626276
# 0:00:35.339899
# 20200403 unzip finished
# 2020-04-03
# trade finished
# 0:10:09.908098
# 0:00:38.348307
# 20200407 unzip finished
# 2020-04-07
# trade finished
# 0:11:34.182876
# 0:00:37.698418
# 20200408 unzip finished
# 2020-04-08
# trade finished
# 0:12:17.173702
# 0:00:36.225965
# 20200409 unzip finished
# 2020-04-09
# trade finished
# 0:11:17.368517
# 0:00:40.482277
# 20200410 unzip finished
# 2020-04-10
# trade finished
# 0:12:24.102932
# 0:00:31.229746
# 20200413 unzip finished
# 2020-04-13
# trade finished
# 0:09:31.809788
# 0:00:36.717334
# 20200414 unzip finished
# 2020-04-14
# trade finished
# 0:09:59.374833
# 0:00:40.758808
# 20200415 unzip finished
# 2020-04-15
# trade finished
# 0:12:18.886606
# 0:00:40.947589
# 20200416 unzip finished
# 2020-04-16
# trade finished
# 0:11:22.153524
# 0:00:43.667253
# 20200417 unzip finished
# 2020-04-17
# trade finished
# 0:12:07.857648
# 0:00:37.193276
# 20200420 unzip finished
# 2020-04-20
# trade finished
# 0:10:15.761050
# 0:00:36.399577
# 20200421 unzip finished
# 2020-04-21
# trade finished
# 0:10:37.311509
# 0:00:36.653005
# 20200422 unzip finished
# 2020-04-22
# trade finished
# 0:10:40.883968
# 0:00:39.457985
# 20200423 unzip finished
# 2020-04-23
# trade finished
# 0:11:15.848691
# 0:00:38.487439
# 20200424 unzip finished
# 2020-04-24
# trade finished
# 0:11:01.786853
# 0:00:33.937829
# 20200427 unzip finished
# 2020-04-27
# trade finished
# 0:09:41.981184
# 0:00:38.590423
# 20200428 unzip finished
# 2020-04-28
# trade finished
# 0:12:14.685505
# 0:00:35.267504
# 20200429 unzip finished
# 2020-04-29
# trade finished
# 0:09:51.486784
# 0:00:39.524436
# 20200430 unzip finished
# 2020-04-30
# trade finished
# 0:12:21.286301
# 0:00:40.076221
# 20200506 unzip finished
# 2020-05-06
# trade finished
# 0:10:52.168082
# 0:00:37.061648
# 20200507 unzip finished
# 2020-05-07
# trade finished
# 0:10:46.504191
# 0:00:37.659479
# 20200508 unzip finished
# 2020-05-08
# trade finished
# 0:10:47.798391
# 0:00:40.599462
# 20200511 unzip finished
# 2020-05-11
# trade finished
# 0:12:15.326852
# 0:00:35.698104
# 20200512 unzip finished
# 2020-05-12
# trade finished
# 0:11:08.177556
# 0:00:33.925048
# 20200513 unzip finished
# 2020-05-13
# trade finished
# 0:10:18.871271
# 0:00:34.153266
# 20200514 unzip finished
# 2020-05-14
# trade finished
# 0:10:17.515297
# 0:00:33.468676
# 20200515 unzip finished
# 2020-05-15
# trade finished
# 0:10:26.296732
# 0:00:42.169805
# 20200518 unzip finished
# 2020-05-18
# trade finished
# 0:11:37.514539
# 0:00:34.275962
# 20200519 unzip finished
# 2020-05-19
# trade finished
# 0:10:26.738341
# 0:00:35.632263
# 20200520 unzip finished
# 2020-05-20
# trade finished
# 0:11:11.843628
# 0:00:37.013968
# 20200521 unzip finished
# 2020-05-21
# trade finished
# 0:10:48.971349
# 0:00:34.619339
# 20200522 unzip finished
# 2020-05-22
# trade finished
# 0:10:44.729747
# 0:00:20.340951
# 20200525 unzip finished
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000001.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000002.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000004.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000005.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000006.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000007.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000008.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000009.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000010.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000011.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000012.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000014.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000016.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000017.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000019.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000020.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000021.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000023.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000025.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000026.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000027.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000028.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000030.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000031.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000032.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000034.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000035.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000036.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000037.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000038.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000039.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000040.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000042.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000045.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000046.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000048.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000049.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000050.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000055.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000056.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000058.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000059.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000060.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000061.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000062.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000063.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000065.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000066.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000068.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000069.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000070.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000078.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000088.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000089.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000090.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000096.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000099.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000100.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000150.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000151.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000153.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000156.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000157.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000158.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000159.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000166.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000301.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000333.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000338.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000400.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000401.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000402.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000403.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000404.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000407.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000408.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000409.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000410.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000411.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000413.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000415.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000416.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000417.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000419.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000420.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000421.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000422.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000423.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000425.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000426.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000428.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000429.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000430.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000488.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000498.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000501.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000502.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000503.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000504.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000505.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000506.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000507.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000509.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000510.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000513.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000514.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000516.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000517.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000518.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000519.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000520.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000521.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000523.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000524.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000525.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000526.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000528.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000529.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000530.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000531.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000532.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000533.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000534.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000536.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000537.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000538.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000539.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000540.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000541.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000543.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000544.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000545.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000546.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000547.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000548.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000550.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000551.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000552.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000553.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000554.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000555.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000557.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000558.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000559.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000560.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000561.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000563.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000564.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000565.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000566.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000567.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000568.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000570.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000571.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000572.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000573.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000576.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000581.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000582.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000584.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000585.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000586.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000587.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000589.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000590.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000591.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000592.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000593.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000595.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000596.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000597.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000598.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000599.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000600.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000601.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000603.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000605.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000606.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000607.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000608.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000609.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000610.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000611.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000612.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000613.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000615.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000616.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000617.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000619.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000620.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000622.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000623.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000625.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000626.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000627.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000628.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000629.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000630.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000631.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000632.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000633.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000635.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000636.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000637.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000638.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000639.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000650.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000651.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000652.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000655.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000656.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000657.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000659.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000661.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000662.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000663.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000665.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000666.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000667.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000669.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000671.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000672.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000673.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000676.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000677.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000678.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000679.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000680.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000681.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000682.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000683.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000685.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000686.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000687.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000688.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000690.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000691.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000692.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000695.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000697.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000698.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000700.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000701.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000702.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000703.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000705.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000707.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000708.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000709.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000710.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000711.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000712.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000713.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000715.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000716.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000717.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000718.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000719.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000720.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000721.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000722.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000723.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000725.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000726.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000727.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000728.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000729.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000731.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000732.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000733.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000735.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000736.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000737.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000738.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000739.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000750.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000751.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000752.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000753.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000755.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000756.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000757.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000758.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000759.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000760.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000761.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000762.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000766.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000767.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000768.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000776.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000777.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000778.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000779.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000780.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000782.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000783.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000785.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000786.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000788.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000789.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000790.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000791.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000793.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000795.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000796.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000797.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000798.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000799.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000800.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000801.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000802.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000803.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000806.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000807.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000809.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000810.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000811.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000812.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000813.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000815.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000816.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000818.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000819.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000820.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000821.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000822.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000823.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000825.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000826.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000828.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000829.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000830.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000831.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000833.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000835.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000836.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000837.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000838.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000839.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000848.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000850.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000851.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000852.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000856.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000858.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000859.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000860.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000861.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000862.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000863.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000868.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000869.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000875.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000876.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000877.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000878.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000880.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000881.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000882.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000883.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000885.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000886.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000887.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000888.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000889.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000890.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000892.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000893.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000895.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000897.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000898.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000899.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000900.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000901.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000902.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000903.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000905.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000906.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000908.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000909.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000910.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000911.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000912.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000913.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000915.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000917.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000918.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000919.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000920.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000921.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000922.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000923.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000925.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000926.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000927.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000928.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000929.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000930.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000931.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000932.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000933.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000935.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000936.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000937.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000938.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000948.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000949.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000950.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000951.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000952.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000953.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000955.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000957.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000958.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000959.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000960.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000961.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000962.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000963.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000965.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000966.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000967.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000968.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000969.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000970.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000971.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000972.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000973.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000975.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000976.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000977.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000978.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000980.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000981.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000982.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000983.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000985.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000987.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000988.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000989.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000990.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000993.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000996.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000997.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000998.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/000999.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/001696.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/001872.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/001896.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/001914.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/001965.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/001979.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002001.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002002.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002003.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002004.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002005.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002006.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002007.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002008.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002009.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002010.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002011.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002012.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002013.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002014.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002015.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002016.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002017.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002019.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002020.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002021.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002022.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002023.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002024.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002025.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002026.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002027.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002028.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002029.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002030.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002031.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002032.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002033.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002034.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002035.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002036.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002037.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002038.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002039.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002040.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002041.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002042.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002043.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002044.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002045.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002046.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002047.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002048.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002049.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002050.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002051.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002052.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002053.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002054.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002055.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002056.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002057.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002058.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002059.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002060.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002061.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002062.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002063.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002064.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002065.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002066.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002067.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002068.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002069.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002071.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002072.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002073.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002075.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002076.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002077.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002078.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002079.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002080.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002081.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002082.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002083.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002084.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002085.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002086.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002087.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002088.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002089.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002090.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002091.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002092.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002093.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002094.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002095.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002096.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002097.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002098.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002099.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002100.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002101.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002102.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002103.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002104.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002105.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002106.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002107.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002108.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002109.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002110.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002111.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002112.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002113.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002114.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002115.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002116.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002117.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002118.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002119.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002120.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002121.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002122.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002123.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002124.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002125.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002126.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002127.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002128.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002129.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002130.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002131.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002132.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002133.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002134.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002135.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002136.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002137.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002138.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002139.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002140.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002141.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002142.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002144.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002145.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002146.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002147.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002148.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002149.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002150.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002151.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002152.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002153.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002154.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002155.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002156.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002157.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002158.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002159.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002160.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002161.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002162.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002163.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002164.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002165.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002166.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002167.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002168.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002169.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002170.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002171.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002172.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002173.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002174.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002175.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002176.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002177.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002178.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002179.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002180.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002181.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002182.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002183.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002184.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002185.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002186.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002187.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002188.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002189.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002190.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002191.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002192.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002193.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002194.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002195.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002196.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002197.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002198.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002199.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002200.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002201.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002202.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002203.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002204.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002205.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002206.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002207.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002208.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002209.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002210.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002211.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002212.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002213.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002214.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002215.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002216.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002217.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002218.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002219.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002220.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002221.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002222.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002223.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002224.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002225.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002226.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002227.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002228.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002229.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002230.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002231.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002232.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002233.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002234.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002235.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002236.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002237.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002238.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002239.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002240.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002241.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002242.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002243.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002244.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002245.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002246.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002247.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002248.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002249.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002250.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002251.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002252.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002253.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002254.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002256.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002258.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002259.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002261.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002262.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002267.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002268.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002269.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002270.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002273.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002276.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002278.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002279.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002281.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002285.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002292.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/002990.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/tick/300835.csv
# {2000001,
#  2000002,
#  2000004,
#  2000005,
#  2000006,
#  2000007,
#  2000008,
#  2000009,
#  2000010,
#  2000011,
#  2000012,
#  2000014,
#  2000016,
#  2000017,
#  2000019,
#  2000020,
#  2000021,
#  2000023,
#  2000025,
#  2000026,
#  2000027,
#  2000028,
#  2000030,
#  2000031,
#  2000032,
#  2000034,
#  2000035,
#  2000036,
#  2000037,
#  2000038,
#  2000039,
#  2000040,
#  2000042,
#  2000045,
#  2000046,
#  2000048,
#  2000049,
#  2000050,
#  2000055,
#  2000056,
#  2000058,
#  2000059,
#  2000060,
#  2000061,
#  2000062,
#  2000063,
#  2000065,
#  2000066,
#  2000068,
#  2000069,
#  2000070,
#  2000078,
#  2000088,
#  2000089,
#  2000090,
#  2000096,
#  2000099,
#  2000100,
#  2000150,
#  2000151,
#  2000153,
#  2000156,
#  2000157,
#  2000158,
#  2000159,
#  2000166,
#  2000301,
#  2000333,
#  2000338,
#  2000400,
#  2000401,
#  2000402,
#  2000403,
#  2000404,
#  2000407,
#  2000408,
#  2000409,
#  2000410,
#  2000411,
#  2000413,
#  2000415,
#  2000416,
#  2000417,
#  2000419,
#  2000420,
#  2000421,
#  2000422,
#  2000423,
#  2000425,
#  2000426,
#  2000428,
#  2000429,
#  2000430,
#  2000488,
#  2000498,
#  2000501,
#  2000502,
#  2000503,
#  2000504,
#  2000505,
#  2000506,
#  2000507,
#  2000509,
#  2000510,
#  2000513,
#  2000514,
#  2000516,
#  2000517,
#  2000518,
#  2000519,
#  2000520,
#  2000521,
#  2000523,
#  2000524,
#  2000525,
#  2000526,
#  2000528,
#  2000529,
#  2000530,
#  2000531,
#  2000532,
#  2000533,
#  2000534,
#  2000536,
#  2000537,
#  2000538,
#  2000539,
#  2000540,
#  2000541,
#  2000543,
#  2000544,
#  2000545,
#  2000546,
#  2000547,
#  2000548,
#  2000550,
#  2000551,
#  2000552,
#  2000553,
#  2000554,
#  2000555,
#  2000557,
#  2000558,
#  2000559,
#  2000560,
#  2000561,
#  2000563,
#  2000564,
#  2000565,
#  2000566,
#  2000567,
#  2000568,
#  2000570,
#  2000571,
#  2000572,
#  2000573,
#  2000576,
#  2000581,
#  2000582,
#  2000584,
#  2000585,
#  2000586,
#  2000587,
#  2000589,
#  2000590,
#  2000591,
#  2000592,
#  2000593,
#  2000595,
#  2000596,
#  2000597,
#  2000598,
#  2000599,
#  2000600,
#  2000601,
#  2000603,
#  2000605,
#  2000606,
#  2000607,
#  2000608,
#  2000609,
#  2000610,
#  2000611,
#  2000612,
#  2000613,
#  2000615,
#  2000616,
#  2000617,
#  2000619,
#  2000620,
#  2000622,
#  2000623,
#  2000625,
#  2000626,
#  2000627,
#  2000628,
#  2000629,
#  2000630,
#  2000631,
#  2000632,
#  2000633,
#  2000635,
#  2000636,
#  2000637,
#  2000638,
#  2000639,
#  2000650,
#  2000651,
#  2000652,
#  2000655,
#  2000656,
#  2000657,
#  2000659,
#  2000661,
#  2000662,
#  2000663,
#  2000665,
#  2000666,
#  2000667,
#  2000669,
#  2000671,
#  2000672,
#  2000673,
#  2000676,
#  2000677,
#  2000678,
#  2000679,
#  2000680,
#  2000681,
#  2000682,
#  2000683,
#  2000685,
#  2000686,
#  2000687,
#  2000688,
#  2000690,
#  2000691,
#  2000692,
#  2000695,
#  2000697,
#  2000698,
#  2000700,
#  2000701,
#  2000702,
#  2000703,
#  2000705,
#  2000707,
#  2000708,
#  2000709,
#  2000710,
#  2000711,
#  2000712,
#  2000713,
#  2000715,
#  2000716,
#  2000717,
#  2000718,
#  2000719,
#  2000720,
#  2000721,
#  2000722,
#  2000723,
#  2000725,
#  2000726,
#  2000727,
#  2000728,
#  2000729,
#  2000731,
#  2000732,
#  2000733,
#  2000735,
#  2000736,
#  2000737,
#  2000738,
#  2000739,
#  2000750,
#  2000751,
#  2000752,
#  2000753,
#  2000755,
#  2000756,
#  2000757,
#  2000758,
#  2000759,
#  2000760,
#  2000761,
#  2000762,
#  2000766,
#  2000767,
#  2000768,
#  2000776,
#  2000777,
#  2000778,
#  2000779,
#  2000780,
#  2000782,
#  2000783,
#  2000785,
#  2000786,
#  2000788,
#  2000789,
#  2000790,
#  2000791,
#  2000793,
#  2000795,
#  2000796,
#  2000797,
#  2000798,
#  2000799,
#  2000800,
#  2000801,
#  2000802,
#  2000803,
#  2000806,
#  2000807,
#  2000809,
#  2000810,
#  2000811,
#  2000812,
#  2000813,
#  2000815,
#  2000816,
#  2000818,
#  2000819,
#  2000820,
#  2000821,
#  2000822,
#  2000823,
#  2000825,
#  2000826,
#  2000828,
#  2000829,
#  2000830,
#  2000831,
#  2000833,
#  2000835,
#  2000836,
#  2000837,
#  2000838,
#  2000839,
#  2000848,
#  2000850,
#  2000851,
#  2000852,
#  2000856,
#  2000858,
#  2000859,
#  2000860,
#  2000861,
#  2000862,
#  2000863,
#  2000868,
#  2000869,
#  2000875,
#  2000876,
#  2000877,
#  2000878,
#  2000880,
#  2000881,
#  2000882,
#  2000883,
#  2000885,
#  2000886,
#  2000887,
#  2000888,
#  2000889,
#  2000890,
#  2000892,
#  2000893,
#  2000895,
#  2000897,
#  2000898,
#  2000899,
#  2000900,
#  2000901,
#  2000902,
#  2000903,
#  2000905,
#  2000906,
#  2000908,
#  2000909,
#  2000910,
#  2000911,
#  2000912,
#  2000913,
#  2000915,
#  2000917,
#  2000918,
#  2000919,
#  2000920,
#  2000921,
#  2000922,
#  2000923,
#  2000925,
#  2000926,
#  2000927,
#  2000928,
#  2000929,
#  2000930,
#  2000931,
#  2000932,
#  2000933,
#  2000935,
#  2000936,
#  2000937,
#  2000938,
#  2000948,
#  2000949,
#  2000950,
#  2000951,
#  2000952,
#  2000953,
#  2000955,
#  2000957,
#  2000958,
#  2000959,
#  2000960,
#  2000961,
#  2000962,
#  2000963,
#  2000965,
#  2000966,
#  2000967,
#  2000968,
#  2000969,
#  2000970,
#  2000971,
#  2000972,
#  2000973,
#  2000975,
#  2000976,
#  2000977,
#  2000978,
#  2000980,
#  2000981,
#  2000982,
#  2000983,
#  2000985,
#  2000987,
#  2000988,
#  2000989,
#  2000990,
#  2000993,
#  2000996,
#  2000997,
#  2000998,
#  2000999,
#  2001696,
#  2001872,
#  2001896,
#  2001914,
#  2001965,
#  2001979,
#  2002001,
#  2002002,
#  2002003,
#  2002004,
#  2002005,
#  2002006,
#  2002007,
#  2002008,
#  2002009,
#  2002010,
#  2002011,
#  2002012,
#  2002013,
#  2002014,
#  2002015,
#  2002016,
#  2002017,
#  2002019,
#  2002020,
#  2002021,
#  2002022,
#  2002023,
#  2002024,
#  2002025,
#  2002026,
#  2002027,
#  2002028,
#  2002029,
#  2002030,
#  2002031,
#  2002032,
#  2002033,
#  2002034,
#  2002035,
#  2002036,
#  2002037,
#  2002038,
#  2002039,
#  2002040,
#  2002041,
#  2002042,
#  2002043,
#  2002044,
#  2002045,
#  2002046,
#  2002047,
#  2002048,
#  2002049,
#  2002050,
#  2002051,
#  2002052,
#  2002053,
#  2002054,
#  2002055,
#  2002056,
#  2002057,
#  2002058,
#  2002059,
#  2002060,
#  2002061,
#  2002062,
#  2002063,
#  2002064,
#  2002065,
#  2002066,
#  2002067,
#  2002068,
#  2002069,
#  2002071,
#  2002072,
#  2002073,
#  2002075,
#  2002076,
#  2002077,
#  2002078,
#  2002079,
#  2002080,
#  2002081,
#  2002082,
#  2002083,
#  2002084,
#  2002085,
#  2002086,
#  2002087,
#  2002088,
#  2002089,
#  2002090,
#  2002091,
#  2002092,
#  2002093,
#  2002094,
#  2002095,
#  2002096,
#  2002097,
#  2002098,
#  2002099,
#  2002100,
#  2002101,
#  2002102,
#  2002103,
#  2002104,
#  2002105,
#  2002106,
#  2002107,
#  2002108,
#  2002109,
#  2002110,
#  2002111,
#  2002112,
#  2002113,
#  2002114,
#  2002115,
#  2002116,
#  2002117,
#  2002118,
#  2002119,
#  2002120,
#  2002121,
#  2002122,
#  2002123,
#  2002124,
#  2002125,
#  2002126,
#  2002127,
#  2002128,
#  2002129,
#  2002130,
#  2002131,
#  2002132,
#  2002133,
#  2002134,
#  2002135,
#  2002136,
#  2002137,
#  2002138,
#  2002139,
#  2002140,
#  2002141,
#  2002142,
#  2002144,
#  2002145,
#  2002146,
#  2002147,
#  2002148,
#  2002149,
#  2002150,
#  2002151,
#  2002152,
#  2002153,
#  2002154,
#  2002155,
#  2002156,
#  2002157,
#  2002158,
#  2002159,
#  2002160,
#  2002161,
#  2002162,
#  2002163,
#  2002164,
#  2002165,
#  2002166,
#  2002167,
#  2002168,
#  2002169,
#  2002170,
#  2002171,
#  2002172,
#  2002173,
#  2002174,
#  2002175,
#  2002176,
#  2002177,
#  2002178,
#  2002179,
#  2002180,
#  2002181,
#  2002182,
#  2002183,
#  2002184,
#  2002185,
#  2002186,
#  2002187,
#  2002188,
#  2002189,
#  2002190,
#  2002191,
#  2002192,
#  2002193,
#  2002194,
#  2002195,
#  2002196,
#  2002197,
#  2002198,
#  2002199,
#  2002200,
#  2002201,
#  2002202,
#  2002203,
#  2002204,
#  2002205,
#  2002206,
#  2002207,
#  2002208,
#  2002209,
#  2002210,
#  2002211,
#  2002212,
#  2002213,
#  2002214,
#  2002215,
#  2002216,
#  2002217,
#  2002218,
#  2002219,
#  2002220,
#  2002221,
#  2002222,
#  2002223,
#  2002224,
#  2002225,
#  2002226,
#  2002227,
#  2002228,
#  2002229,
#  2002230,
#  2002231,
#  2002232,
#  2002233,
#  2002234,
#  2002235,
#  2002236,
#  2002237,
#  2002238,
#  2002239,
#  2002240,
#  2002241,
#  2002242,
#  2002243,
#  2002244,
#  2002245,
#  2002246,
#  2002247,
#  2002248,
#  2002249,
#  2002250,
#  2002251,
#  2002252,
#  2002253,
#  2002254,
#  2002256,
#  2002258,
#  2002259,
#  2002261,
#  2002262,
#  2002267,
#  2002268,
#  2002269,
#  2002270,
#  2002273,
#  2002276,
#  2002278,
#  2002279,
#  2002281,
#  2002285,
#  2002292,
#  2002990,
#  2300835}
#             ID  max_volume    max_amount     skey  cum_volume  cum_amount
# 0     SZ000001  41017078.0  5.287694e+08  2000001         NaN         NaN
# 1     SZ000002  51276102.0  1.300390e+09  2000002         NaN         NaN
# 2     SZ000004   1482843.0  4.127411e+07  2000004         NaN         NaN
# 3     SZ000005   2738504.0  6.885460e+06  2000005         NaN         NaN
# 4     SZ000006   4367771.0  2.055259e+07  2000006         NaN         NaN
# ...        ...         ...           ...      ...         ...         ...
# 727   SZ002281  13579673.0  3.740188e+08  2002281         NaN         NaN
# 731   SZ002285  13127150.0  3.400329e+07  2002285         NaN         NaN
# 738   SZ002292  11147092.0  6.453698e+07  2002292         NaN         NaN
# 1402  SZ002990     96968.0  5.101541e+06  2002990         NaN         NaN
# 2210  SZ300835     32200.0  9.252300e+05  2300835         NaN         NaN
#
# [721 rows x 6 columns]
#             ID  max_volume    max_amount     skey  cum_volume  cum_amount
# 0     SZ000001  41017078.0  5.287694e+08  2000001         NaN         NaN
# 1     SZ000002  51276102.0  1.300390e+09  2000002         NaN         NaN
# 2     SZ000004   1482843.0  4.127411e+07  2000004         NaN         NaN
# 3     SZ000005   2738504.0  6.885460e+06  2000005         NaN         NaN
# 4     SZ000006   4367771.0  2.055259e+07  2000006         NaN         NaN
# ...        ...         ...           ...      ...         ...         ...
# 727   SZ002281  13579673.0  3.740188e+08  2002281         NaN         NaN
# 731   SZ002285  13127150.0  3.400329e+07  2002285         NaN         NaN
# 738   SZ002292  11147092.0  6.453698e+07  2002292         NaN         NaN
# 1402  SZ002990     96968.0  5.101541e+06  2002990         NaN         NaN
# 2210  SZ300835     32200.0  9.252300e+05  2300835         NaN         NaN
#
# [721 rows x 6 columns]
# 2020-05-25
# trade finished
# 0:06:08.717779
# 0:00:32.584514
# 20200526 unzip finished
# /home/work516/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:282: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /home/work516/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:283: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /home/work516/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:284: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
# 2020-05-26
# trade finished
# 0:09:27.912688
# 0:00:32.421389
# 20200527 unzip finished
# 2020-05-27
# trade finished
# 0:10:55.450550
# 0:00:35.781700
# 20200528 unzip finished
# 2020-05-28
# trade finished
# 0:10:09.473995
# 0:00:34.528610
# 20200529 unzip finished
# set()
#             ID  max_volume  max_amount     skey  cum_volume   cum_amount
# 1865  SZ300475   1796100.0  14268967.1  2300475    12425863  42682178.96
#             ID  max_volume  max_amount     skey  cum_volume   cum_amount
# 1865  SZ300475   1796100.0  14268967.1  2300475    12425863  42682178.96
# 2020-05-29
# trade finished
# 0:09:56.956703
