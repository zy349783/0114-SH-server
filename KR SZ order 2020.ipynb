# %%
import pymongo
import pandas as pd
import pickle
import datetime
import time
import gzip
import lzma
import pytz


def DB(host, db_name, user, passwd):
    auth_db = db_name if user not in ('admin', 'root') else 'admin'
    uri = 'mongodb://%s:%s@%s/?authSource=%s' % (user, passwd, host, auth_db)
    return DBObj(uri, db_name=db_name)


class DBObj(object):
    def __init__(self, uri, symbol_column='skey', db_name='white_db'):
        self.db_name = db_name
        self.uri = uri
        self.client = pymongo.MongoClient(self.uri)
        self.db = self.client[self.db_name]
        self.chunk_size = 20000
        self.symbol_column = symbol_column
        self.date_column = 'date'

    def parse_uri(self, uri):
        # mongodb://user:password@example.com
        return uri.strip().replace('mongodb://', '').strip('/').replace(':', ' ').replace('@', ' ').split(' ')

    def drop_table(self, table_name):
        self.db.drop_collection(table_name)

    def rename_table(self, old_table, new_table):
        self.db[old_table].rename(new_table)

    def write(self, table_name, df):
        if len(df) == 0: return

        multi_date = False

        if self.date_column in df.columns:
            date = str(df.head(1)[self.date_column].iloc[0])
            multi_date = len(df[self.date_column].unique()) > 1
        else:
            raise Exception('DataFrame should contain date column')

        collection = self.db[table_name]
        collection.create_index([('date', pymongo.ASCENDING), ('symbol', pymongo.ASCENDING)], background=True)
        collection.create_index([('symbol', pymongo.ASCENDING), ('date', pymongo.ASCENDING)], background=True)

        if multi_date:
            for (date, symbol), sub_df in df.groupby([self.date_column, self.symbol_column]):
                date = str(date)
                symbol = int(symbol)
                collection.delete_many({'date': date, 'symbol': symbol})
                self.write_single(collection, date, symbol, sub_df)
        else:
            for symbol, sub_df in df.groupby([self.symbol_column]):
                collection.delete_many({'date': date, 'symbol': symbol})
                self.write_single(collection, date, symbol, sub_df)

    def write_single(self, collection, date, symbol, df):
        for start in range(0, len(df), self.chunk_size):
            end = min(start + self.chunk_size, len(df))
            df_seg = df[start:end]
            version = 1
            seg = {'ver': version, 'data': self.ser(df_seg, version), 'date': date, 'symbol': symbol, 'start': start}
            collection.insert_one(seg)

    def build_query(self, start_date=None, end_date=None, symbol=None):
        query = {}

        def parse_date(x):
            if type(x) == str:
                if len(x) != 8:
                    raise Exception("`date` must be YYYYMMDD format")
                return x
            elif type(x) == datetime.datetime or type(x) == datetime.date:
                return x.strftime("%Y%m%d")
            elif type(x) == int:
                return parse_date(str(x))
            else:
                raise Exception("invalid `date` type: " + str(type(x)))

        if start_date is not None or end_date is not None:
            query['date'] = {}
            if start_date is not None:
                query['date']['$gte'] = parse_date(start_date)
            if end_date is not None:
                query['date']['$lte'] = parse_date(end_date)

        def parse_symbol(x):
            if type(x) == int:
                return x
            else:
                return int(x)

        if symbol:
            if type(symbol) == list or type(symbol) == tuple:
                query['symbol'] = {'$in': [parse_symbol(x) for x in symbol]}
            else:
                query['symbol'] = parse_symbol(symbol)

        return query

    def delete(self, table_name, start_date=None, end_date=None, symbol=None):
        collection = self.db[table_name]

        query = self.build_query(start_date, end_date, symbol)
        if not query:
            print('cannot delete the whole table')
            return None

        collection.delete_many(query)

    def read(self, table_name, start_date=None, end_date=None, symbol=None):
        collection = self.db[table_name]

        query = self.build_query(start_date, end_date, symbol)
        if not query:
            print('cannot read the whole table')
            return None

        segs = []
        for x in collection.find(query):
            x['data'] = self.deser(x['data'], x['ver'])
            segs.append(x)
        segs.sort(key=lambda x: (x['symbol'], x['date'], x['start']))
        return pd.concat([x['data'] for x in segs], ignore_index=True) if segs else None

    def list_tables(self):
        return self.db.collection_names()

    def list_dates(self, table_name, start_date=None, end_date=None, symbol=None):
        collection = self.db[table_name]
        dates = set()
        if start_date is None:
            start_date = '00000000'
        if end_date is None:
            end_date = '99999999'
        for x in collection.find(self.build_query(start_date, end_date, symbol), {"date": 1, '_id': 0}):
            dates.add(x['date'])
        return sorted(list(dates))

    def ser(self, s, version):
        pickle_protocol = 4
        if version == 1:
            return gzip.compress(pickle.dumps(s, protocol=pickle_protocol), compresslevel=2)
        elif version == 2:
            return lzma.compress(pickle.dumps(s, protocol=pickle_protocol), preset=1)
        else:
            raise Exception('unknown version')

    def deser(self, s, version):
        def unpickle(s):
            return pickle.loads(s)

        if version == 1:
            return unpickle(gzip.decompress(s))
        elif version == 2:
            return unpickle(lzma.decompress(s))
        else:
            raise Exception('unknown version')


def patch_pandas_pickle():
    if pd.__version__ < '0.24':
        import sys
        from types import ModuleType
        from pandas.core.internals import BlockManager
        pkg_name = 'pandas.core.internals.managers'
        if pkg_name not in sys.modules:
            m = ModuleType(pkg_name)
            m.BlockManager = BlockManager
            sys.modules[pkg_name] = m
patch_pandas_pickle()
    
    


import pandas as pd
import random
import numpy as np
import glob
import os
import pickle
import datetime
import time
pd.set_option("max_columns", 200)

startTm = datetime.datetime.now()
readPath = '/mnt/ShareWithServer/day_stock_20200820/***'
dataPathLs = np.array(glob.glob(readPath))
dataPathLs = dataPathLs[[np.array([os.path.basename(i).split('.')[0][:2] == 'SZ' for i in dataPathLs])]]
db = pd.DataFrame()
for p in dataPathLs:
    dayData = pd.read_csv(p, compression='gzip')
    db = pd.concat([db, dayData])
print(datetime.datetime.now() - startTm)

year = "2020"
startDate = '20200721'
endDate = '20200721'
readPath = '/mnt/Kevin_zhenyu/KR_daily_data/***'
dataPathLs = np.array(glob.glob(readPath))
dateLs = np.array([os.path.basename(i) for i in dataPathLs])
dataPathLs = dataPathLs[(dateLs >= startDate) & (dateLs <= endDate)]

for data in np.sort(dataPathLs):
    
    readPath = data + '/SZ/order/***'
    dataPathLs = np.array(glob.glob(readPath))
    dateLs = np.array([int(os.path.basename(i).split('.')[0]) for i in dataPathLs])
    dataPathLs = dataPathLs[(dateLs < 4000) | ((dateLs > 300000) & (dateLs < 310000))]
    OrderLog = []
    ll = []
    
    for i in dataPathLs:
        try:
            df = pd.read_csv(i, encoding='GBK')
        except:
            print("empty data")
            print(i)
            ll.append(int(os.path.basename(i).split('.')[0]))
            continue
        df["SecurityID"] = int(os.path.basename(i).split('.')[0])
        OrderLog += [df]
    OrderLog = pd.concat(OrderLog).reset_index(drop=True)
    OrderLog = OrderLog[OrderLog["ChannelNo"] != 4001]
    
    OrderLog = OrderLog.rename(columns={"OrdType": "OrderType"})
    OrderLog["date"] = OrderLog["TransactTime"].iloc[0]//1000000000
    OrderLog["OrderType"] = np.where(OrderLog["OrderType"] == 'U', 3, OrderLog["OrderType"])
    OrderLog["skey"] = OrderLog["SecurityID"] + 2000000
    OrderLog["clockAtArrival"] = OrderLog["TransactTime"].astype(str).apply(lambda x: np.int64(datetime.datetime.strptime(x, '%Y%m%d%H%M%S%f').timestamp()*1e6))
    OrderLog['datetime'] = OrderLog["clockAtArrival"].apply(lambda x: datetime.datetime.fromtimestamp(x/1e6))
    OrderLog["time"] = (OrderLog['TransactTime'] - int(OrderLog['TransactTime'].iloc[0]//1000000000*1000000000)).astype(np.int64)*1000
    
    for col in ["skey", "date", "ApplSeqNum", "OrderQty", "Side", "OrderType"]:
        OrderLog[col] = OrderLog[col].astype('int32')
#     for cols in ["Price"]:
#         print(cols)
#         print(OrderLog[cols].astype(str).apply(lambda x: len(str(x.split('.')[1]))).unique())
    
    assert(OrderLog[((OrderLog["Side"] != 1) & (OrderLog["Side"] != 2)) | (OrderLog["OrderType"].isnull())].shape[0] == 0)
    da_te = str(OrderLog["date"].iloc[0]) 
    da_te = da_te[:4] + '-' + da_te[4:6] + '-' + da_te[6:8]
    db1 = db[db["date"] == da_te]
    sl = (db1["ID"].str[2:].astype(int) + 2000000).unique()
    del db1
    try:
        assert(len(set(sl) - set(OrderLog["skey"].unique())) == 0)
    except:
        print("less stocks")
        display(set(sl) - set(OrderLog["skey"].unique()))
    if len(set(OrderLog["skey"].unique()) - set(sl)) != 0:
        print("more stocks")
        print(set(OrderLog["skey"].unique()) - set(sl))
    
    OrderLog = OrderLog.rename(columns={"Side":"order_side", "OrderType":"order_type", "Price":"order_price", "OrderQty":"order_qty"})
    OrderLog = OrderLog[["skey", "date", "time", "clockAtArrival", "datetime", "ApplSeqNum", "order_side", "order_type", "order_price",
                                                 "order_qty"]]
    
    
    
    startDate = str(OrderLog['date'].iloc[0])
    endDate = str(OrderLog['date'].iloc[0])
    database_name = 'com_md_eq_cn'
    user = "zhenyuy"
    password = "bnONBrzSMGoE"
    db1 = DB("192.168.10.178", database_name, user, password)
    trade = db1.read('md_trade', start_date=startDate, end_date=endDate)
    trade = trade[trade['skey'] > 2000000]
    t1 = trade.groupby('skey')['BidApplSeqNum'].unique().reset_index()
    t2 = trade.groupby('skey')['OfferApplSeqNum'].unique().reset_index()
    t3 = OrderLog.groupby('skey')['ApplSeqNum'].unique().reset_index()
    t = pd.merge(t1, t2, on='skey', how='outer')
    t['union'] = [list(set(a) | set(b)) for a, b in zip(t.BidApplSeqNum, t.OfferApplSeqNum)]
    t = pd.merge(t, t3, on='skey')
    t['less'] = [len(set(a) - set(b)) for a, b in zip(t.union, t.ApplSeqNum)]
    t['less1'] = [list(set(a) - set(b))[0] for a, b in zip(t.union, t.ApplSeqNum)]
    assert(t[t['less'] > 1].shape[0] == 0)

    print(OrderLog["date"].iloc[0])
    print("order finished")

    database_name = 'com_md_eq_cn'
    user = "zhenyuy"
    password = "bnONBrzSMGoE"

    db1 = DB("192.168.10.178", database_name, user, password)
    db1.write('md_order', OrderLog)
    
    del OrderLog
    
    print(datetime.datetime.now() - startTm)
    
#     pd.set_option("max_rows", 200)
#     display(OrderLog.dtypes)
# Out:
# /home/work516/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:195: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
# 0:06:32.849805
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-2-05172e7de4e2> in <module>
#     271     password = "bnONBrzSMGoE"
#     272     db1 = DB("192.168.10.178", database_name, user, password)
# --> 273     trade = db1.read('md_trade', start_date=startDate, end_date=endDate)
#     274     trade = trade[trade['skey'] > 2000000]
#     275     t1 = trade.groupby('skey')['BidApplSeqNum'].unique().reset_index()
#
# <ipython-input-2-05172e7de4e2> in read(self, table_name, start_date, end_date, symbol)
#     125         segs = []
#     126         for x in collection.find(query):
# --> 127             x['data'] = self.deser(x['data'], x['ver'])
#     128             segs.append(x)
#     129         segs.sort(key=lambda x: (x['symbol'], x['date'], x['start']))
#
# <ipython-input-2-05172e7de4e2> in deser(self, s, version)
#     162             return unpickle(lzma.decompress(s))
#     163         else:
# --> 164             raise Exception('unknown version')
#     165
#     166
#
# Exception: unknown version

# %%
import pymongo
import pandas as pd
import pickle
import datetime
import time
import gzip
import lzma
import pytz


def DB(host, db_name, user, passwd):
    auth_db = db_name if user not in ('admin', 'root') else 'admin'
    uri = 'mongodb://%s:%s@%s/?authSource=%s' % (user, passwd, host, auth_db)
    return DBObj(uri, db_name=db_name)


class DBObj(object):
    def __init__(self, uri, symbol_column='skey', db_name='white_db'):
        self.db_name = db_name
        self.uri = uri
        self.client = pymongo.MongoClient(self.uri)
        self.db = self.client[self.db_name]
        self.chunk_size = 20000
        self.symbol_column = symbol_column
        self.date_column = 'date'

    def parse_uri(self, uri):
        # mongodb://user:password@example.com
        return uri.strip().replace('mongodb://', '').strip('/').replace(':', ' ').replace('@', ' ').split(' ')

    def drop_table(self, table_name):
        self.db.drop_collection(table_name)

    def rename_table(self, old_table, new_table):
        self.db[old_table].rename(new_table)

    def write(self, table_name, df):
        if len(df) == 0: return

        multi_date = False

        if self.date_column in df.columns:
            date = str(df.head(1)[self.date_column].iloc[0])
            multi_date = len(df[self.date_column].unique()) > 1
        else:
            raise Exception('DataFrame should contain date column')

        collection = self.db[table_name]
        collection.create_index([('date', pymongo.ASCENDING), ('symbol', pymongo.ASCENDING)], background=True)
        collection.create_index([('symbol', pymongo.ASCENDING), ('date', pymongo.ASCENDING)], background=True)

        if multi_date:
            for (date, symbol), sub_df in df.groupby([self.date_column, self.symbol_column]):
                date = str(date)
                symbol = int(symbol)
                collection.delete_many({'date': date, 'symbol': symbol})
                self.write_single(collection, date, symbol, sub_df)
        else:
            for symbol, sub_df in df.groupby([self.symbol_column]):
                collection.delete_many({'date': date, 'symbol': symbol})
                self.write_single(collection, date, symbol, sub_df)

    def write_single(self, collection, date, symbol, df):
        for start in range(0, len(df), self.chunk_size):
            end = min(start + self.chunk_size, len(df))
            df_seg = df[start:end]
            version = 1
            seg = {'ver': version, 'data': self.ser(df_seg, version), 'date': date, 'symbol': symbol, 'start': start}
            collection.insert_one(seg)

    def build_query(self, start_date=None, end_date=None, symbol=None):
        query = {}

        def parse_date(x):
            if type(x) == str:
                if len(x) != 8:
                    raise Exception("`date` must be YYYYMMDD format")
                return x
            elif type(x) == datetime.datetime or type(x) == datetime.date:
                return x.strftime("%Y%m%d")
            elif type(x) == int:
                return parse_date(str(x))
            else:
                raise Exception("invalid `date` type: " + str(type(x)))

        if start_date is not None or end_date is not None:
            query['date'] = {}
            if start_date is not None:
                query['date']['$gte'] = parse_date(start_date)
            if end_date is not None:
                query['date']['$lte'] = parse_date(end_date)

        def parse_symbol(x):
            if type(x) == int:
                return x
            else:
                return int(x)

        if symbol:
            if type(symbol) == list or type(symbol) == tuple:
                query['symbol'] = {'$in': [parse_symbol(x) for x in symbol]}
            else:
                query['symbol'] = parse_symbol(symbol)

        return query

    def delete(self, table_name, start_date=None, end_date=None, symbol=None):
        collection = self.db[table_name]

        query = self.build_query(start_date, end_date, symbol)
        if not query:
            print('cannot delete the whole table')
            return None

        collection.delete_many(query)

    def read(self, table_name, start_date=None, end_date=None, symbol=None):
        collection = self.db[table_name]

        query = self.build_query(start_date, end_date, symbol)
        if not query:
            print('cannot read the whole table')
            return None

        segs = []
        for x in collection.find(query):
            x['data'] = self.deser(x['data'], x['ver'])
            segs.append(x)
        segs.sort(key=lambda x: (x['symbol'], x['date'], x['start']))
        return pd.concat([x['data'] for x in segs], ignore_index=True) if segs else None

    def list_tables(self):
        return self.db.collection_names()

    def list_dates(self, table_name, start_date=None, end_date=None, symbol=None):
        collection = self.db[table_name]
        dates = set()
        if start_date is None:
            start_date = '00000000'
        if end_date is None:
            end_date = '99999999'
        for x in collection.find(self.build_query(start_date, end_date, symbol), {"date": 1, '_id': 0}):
            dates.add(x['date'])
        return sorted(list(dates))

    def ser(self, s, version):
        pickle_protocol = 4
        if version == 1:
            return gzip.compress(pickle.dumps(s, protocol=pickle_protocol), compresslevel=2)
        elif version == 2:
            return lzma.compress(pickle.dumps(s, protocol=pickle_protocol), preset=1)
        else:
            raise Exception('unknown version')

    def deser(self, s, version):
        def unpickle(s):
            return pickle.loads(s)

        if version == 1:
            return unpickle(gzip.decompress(s))
        elif version == 2:
            return unpickle(lzma.decompress(s))
        else:
            raise Exception('unknown version')


def patch_pandas_pickle():
    if pd.__version__ < '0.24':
        import sys
        from types import ModuleType
        from pandas.core.internals import BlockManager
        pkg_name = 'pandas.core.internals.managers'
        if pkg_name not in sys.modules:
            m = ModuleType(pkg_name)
            m.BlockManager = BlockManager
            sys.modules[pkg_name] = m
patch_pandas_pickle()
    
    


import pandas as pd
import random
import numpy as np
import glob
import os
import pickle
import datetime
import time
pd.set_option("max_columns", 200)

startTm = datetime.datetime.now()
readPath = '/home/work516/day_stock/***'
dataPathLs = np.array(glob.glob(readPath))
dataPathLs = dataPathLs[[np.array([os.path.basename(i).split('.')[0][:2] == 'SZ' for i in dataPathLs])]]
db = pd.DataFrame()
for p in dataPathLs:
    dayData = pd.read_csv(p, compression='gzip')
    db = pd.concat([db, dayData])
print(datetime.datetime.now() - startTm)

year = "2020"
startDate = '20200108'
endDate = '20200529'
readPath = '/mnt/usb/data/' + year + '/***/***'
dataPathLs = np.array(glob.glob(readPath))
dateLs = np.array([os.path.basename(i) for i in dataPathLs])
dataPathLs = dataPathLs[(dateLs >= startDate) & (dateLs <= endDate)]
less = []

for data in dataPathLs:
    
    
    if len(np.array(glob.glob(data + '/SZ/***'))) == 0:
        if int(os.path.basename(data)) not in date_list["Date"].values:
            continue
        else:
            print(os.path.basename(data) + " less data!!!!!!!!!!!!!!!!!")
            less.append(data)
            continue
    startTm = datetime.datetime.now()
    date = os.path.basename(data)
    rar_path = data + '/SZ/order.7z'
    path = '/mnt/e/unzip_data/2020/SZ'
    path1 = path + '/' + date
    un_path = path1
    cmd = '7za x {} -o{}'.format(rar_path, un_path)
    os.system(cmd)
    print(datetime.datetime.now() - startTm)
    print(date + ' unzip finished')
    
    
    startTm = datetime.datetime.now()
    
    readPath = path1 + '/order/***'
    dataPathLs = np.array(glob.glob(readPath))
    dateLs = np.array([int(os.path.basename(i).split('.')[0]) for i in dataPathLs])
    dataPathLs = dataPathLs[(dateLs < 4000) | ((dateLs > 300000) & (dateLs < 310000))]
    OrderLog = []
    ll = []
    
    for i in dataPathLs:
        try:
            df = pd.read_csv(i, encoding='GBK')
        except:
            print("empty data")
            print(i)
            ll.append(int(os.path.basename(i).split('.')[0]))
            continue
        df["SecurityID"] = int(os.path.basename(i).split('.')[0])
        OrderLog += [df]
    OrderLog = pd.concat(OrderLog).reset_index(drop=True)
    OrderLog = OrderLog[OrderLog["ChannelNo"] != 4001]
    
    OrderLog = OrderLog.rename(columns={"OrdType": "OrderType"})
    OrderLog["date"] = OrderLog["TransactTime"].iloc[0]//1000000000
    OrderLog["OrderType"] = np.where(OrderLog["OrderType"] == 'U', 3, OrderLog["OrderType"])
    OrderLog["skey"] = OrderLog["SecurityID"] + 2000000
    OrderLog["clockAtArrival"] = OrderLog["TransactTime"].astype(str).apply(lambda x: np.int64(datetime.datetime.strptime(x, '%Y%m%d%H%M%S%f').timestamp()*1e6))
    OrderLog['datetime'] = OrderLog["clockAtArrival"].apply(lambda x: datetime.datetime.fromtimestamp(x/1e6))
    OrderLog["time"] = (OrderLog['TransactTime'] - int(OrderLog['TransactTime'].iloc[0]//1000000000*1000000000)).astype(np.int64)*1000
    
    for col in ["skey", "date", "ApplSeqNum", "OrderQty", "Side", "OrderType"]:
        OrderLog[col] = OrderLog[col].astype('int32')
#     for cols in ["Price"]:
#         print(cols)
#         print(OrderLog[cols].astype(str).apply(lambda x: len(str(x.split('.')[1]))).unique())
    
    assert(OrderLog[((OrderLog["Side"] != 1) & (OrderLog["Side"] != 2)) | (OrderLog["OrderType"].isnull())].shape[0] == 0)
    da_te = str(OrderLog["date"].iloc[0]) 
    da_te = da_te[:4] + '-' + da_te[4:6] + '-' + da_te[6:8]
    db1 = db[db["date"] == da_te]
    sl = (db1["ID"].str[2:].astype(int) + 2000000).unique()
    del db1
    try:
        assert(len(set(sl) - set(OrderLog["skey"].unique())) == 0)
    except:
        print("less stocks")
        display(set(sl) - set(OrderLog["skey"].unique()))
    if len(set(OrderLog["skey"].unique()) - set(sl)) != 0:
        print("more stocks")
        print(set(OrderLog["skey"].unique()) - set(sl))
    
    OrderLog = OrderLog.rename(columns={"Side":"order_side", "OrderType":"order_type", "Price":"order_price", "OrderQty":"order_qty"})
    OrderLog = OrderLog[["skey", "date", "time", "clockAtArrival", "datetime", "ApplSeqNum", "order_side", "order_type", "order_price",
                                                 "order_qty"]]
    
    print(OrderLog["date"].iloc[0])
    print("order finished")

    database_name = 'com_md_eq_cn'
    user = "zhenyuy"
    password = "bnONBrzSMGoE"

    db1 = DB("192.168.10.223", database_name, user, password)
    db1.write('md_order', OrderLog)
    
    del OrderLog
    
    print(datetime.datetime.now() - startTm)
    
#     pd.set_option("max_rows", 200)
#     display(OrderLog.dtypes)
# Out:
# /home/work516/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:195: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
# 0:05:43.890879
# 0:00:00.427971
# 20200108 unzip finished
# /home/work516/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (1) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /home/work516/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (4) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /home/work516/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (1,4) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# 20200108
# order finished
# 0:16:03.005811
# 0:00:00.477828
# 20200109 unzip finished
# 20200109
# order finished
# 0:13:15.426550
# 0:00:30.943341
# 20200110 unzip finished
# 20200110
# order finished
# 0:12:32.229609
# 0:00:31.525116
# 20200113 unzip finished
# 20200113
# order finished
# 0:12:07.772094
# 0:00:30.878820
# 20200114 unzip finished
# 20200114
# order finished
# 0:12:34.889077
# 0:00:28.932261
# 20200115 unzip finished
# 20200115
# order finished
# 0:12:52.310549
# 0:00:28.752140
# 20200116 unzip finished
# 20200116
# order finished
# 0:11:39.326341
# 0:00:28.778491
# 20200117 unzip finished
# 20200117
# order finished
# 0:10:52.430577
# 0:00:29.506425
# 20200120 unzip finished
# 20200120
# order finished
# 0:11:34.494080
# 0:00:33.843454
# 20200121 unzip finished
# 20200121
# order finished
# 0:13:31.198763
# 0:00:30.250841
# 20200122 unzip finished
# 20200122
# order finished
# 0:13:49.861541
# 0:00:34.543064
# 20200123 unzip finished
# 20200123
# order finished
# 0:14:11.795835
# 0:00:21.131837
# 20200203 unzip finished
# 20200203
# order finished
# 0:07:01.816822
# 0:00:40.020951
# 20200204 unzip finished
# 20200204
# order finished
# 0:16:37.944411
# 0:00:38.760308
# 20200205 unzip finished
# 20200205
# order finished
# 0:16:05.789005
# 0:00:41.379315
# 20200206 unzip finished
# 20200206
# order finished
# 0:16:29.063686
# 0:00:41.411437
# 20200207 unzip finished
# 20200207
# order finished
# 0:17:15.187679
# 0:00:38.436895
# 20200210 unzip finished
# 20200210
# order finished
# 0:16:06.105969
# 0:00:35.492876
# 20200211 unzip finished
# 20200211
# order finished
# 0:14:46.169314
# 0:00:36.917166
# 20200212 unzip finished
# 20200212
# order finished
# 0:14:51.986104
# 0:00:38.116274
# 20200213 unzip finished
# /home/work516/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (12) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# 20200213
# order finished
# 0:15:37.828132
# 0:00:38.951539
# 20200214 unzip finished
# 20200214
# order finished
# 0:15:21.521482
# 0:00:37.520588
# 20200217 unzip finished
# 20200217
# order finished
# 0:15:42.149687
# 0:00:43.399065
# 20200218 unzip finished
# 20200218
# order finished
# 0:17:04.492161
# 0:00:42.554001
# 20200219 unzip finished
# 20200219
# order finished
# 0:18:10.118846
# 0:00:43.747899
# 20200220 unzip finished
# 20200220
# order finished
# 0:17:50.997227
# 0:00:46.207817
# 20200221 unzip finished
# 20200221
# order finished
# 0:19:29.113650
# 0:00:47.988704
# 20200224 unzip finished
# 20200224
# order finished
# 0:19:16.555799
# 0:00:51.187086
# 20200225 unzip finished
# 20200225
# order finished
# 0:22:37.677841
# 0:00:50.214007
# 20200226 unzip finished
# 20200226
# order finished
# 0:21:07.690863
# 0:00:44.641062
# 20200227 unzip finished
# 20200227
# order finished
# 0:17:41.821160
# 0:00:49.636992
# 20200228 unzip finished
# 20200228
# order finished
# 0:19:27.861095
# 0:00:41.906748
# 20200302 unzip finished
# 20200302
# order finished
# 0:17:41.159079
# 0:00:47.431895
# 20200303 unzip finished
# 20200303
# order finished
# 0:19:42.598107
# 0:01:10.811423
# 20200304 unzip finished
# 20200304
# order finished
# 0:18:04.288845
# 0:01:10.080107
# 20200305 unzip finished
# 20200305
# order finished
# 0:18:29.918373
# 0:00:40.039488
# 20200306 unzip finished
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-1-2ab6c18b4280> in <module>
#     250         df["SecurityID"] = int(os.path.basename(i).split('.')[0])
#     251         OrderLog += [df]
# --> 252     OrderLog = pd.concat(OrderLog).reset_index(drop=True)
#     253     OrderLog = OrderLog[OrderLog["ChannelNo"] != 4001]
#     254
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/reshape/concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     279         verify_integrity=verify_integrity,
#     280         copy=copy,
# --> 281         sort=sort,
#     282     )
#     283
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/reshape/concat.py in __init__(self, objs, axis, join, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     327
#     328         if len(objs) == 0:
# --> 329             raise ValueError("No objects to concatenate")
#     330
#     331         if keys is None:
#
# ValueError: No objects to concatenate

# %%
import pymongo
import pandas as pd
import pickle
import datetime
import time
import gzip
import lzma
import pytz


def DB(host, db_name, user, passwd):
    auth_db = db_name if user not in ('admin', 'root') else 'admin'
    uri = 'mongodb://%s:%s@%s/?authSource=%s' % (user, passwd, host, auth_db)
    return DBObj(uri, db_name=db_name)


class DBObj(object):
    def __init__(self, uri, symbol_column='skey', db_name='white_db'):
        self.db_name = db_name
        self.uri = uri
        self.client = pymongo.MongoClient(self.uri)
        self.db = self.client[self.db_name]
        self.chunk_size = 20000
        self.symbol_column = symbol_column
        self.date_column = 'date'

    def parse_uri(self, uri):
        # mongodb://user:password@example.com
        return uri.strip().replace('mongodb://', '').strip('/').replace(':', ' ').replace('@', ' ').split(' ')

    def drop_table(self, table_name):
        self.db.drop_collection(table_name)

    def rename_table(self, old_table, new_table):
        self.db[old_table].rename(new_table)

    def write(self, table_name, df):
        if len(df) == 0: return

        multi_date = False

        if self.date_column in df.columns:
            date = str(df.head(1)[self.date_column].iloc[0])
            multi_date = len(df[self.date_column].unique()) > 1
        else:
            raise Exception('DataFrame should contain date column')

        collection = self.db[table_name]
        collection.create_index([('date', pymongo.ASCENDING), ('symbol', pymongo.ASCENDING)], background=True)
        collection.create_index([('symbol', pymongo.ASCENDING), ('date', pymongo.ASCENDING)], background=True)

        if multi_date:
            for (date, symbol), sub_df in df.groupby([self.date_column, self.symbol_column]):
                date = str(date)
                symbol = int(symbol)
                collection.delete_many({'date': date, 'symbol': symbol})
                self.write_single(collection, date, symbol, sub_df)
        else:
            for symbol, sub_df in df.groupby([self.symbol_column]):
                collection.delete_many({'date': date, 'symbol': symbol})
                self.write_single(collection, date, symbol, sub_df)

    def write_single(self, collection, date, symbol, df):
        for start in range(0, len(df), self.chunk_size):
            end = min(start + self.chunk_size, len(df))
            df_seg = df[start:end]
            version = 1
            seg = {'ver': version, 'data': self.ser(df_seg, version), 'date': date, 'symbol': symbol, 'start': start}
            collection.insert_one(seg)

    def build_query(self, start_date=None, end_date=None, symbol=None):
        query = {}

        def parse_date(x):
            if type(x) == str:
                if len(x) != 8:
                    raise Exception("`date` must be YYYYMMDD format")
                return x
            elif type(x) == datetime.datetime or type(x) == datetime.date:
                return x.strftime("%Y%m%d")
            elif type(x) == int:
                return parse_date(str(x))
            else:
                raise Exception("invalid `date` type: " + str(type(x)))

        if start_date is not None or end_date is not None:
            query['date'] = {}
            if start_date is not None:
                query['date']['$gte'] = parse_date(start_date)
            if end_date is not None:
                query['date']['$lte'] = parse_date(end_date)

        def parse_symbol(x):
            if type(x) == int:
                return x
            else:
                return int(x)

        if symbol:
            if type(symbol) == list or type(symbol) == tuple:
                query['symbol'] = {'$in': [parse_symbol(x) for x in symbol]}
            else:
                query['symbol'] = parse_symbol(symbol)

        return query

    def delete(self, table_name, start_date=None, end_date=None, symbol=None):
        collection = self.db[table_name]

        query = self.build_query(start_date, end_date, symbol)
        if not query:
            print('cannot delete the whole table')
            return None

        collection.delete_many(query)

    def read(self, table_name, start_date=None, end_date=None, symbol=None):
        collection = self.db[table_name]

        query = self.build_query(start_date, end_date, symbol)
        if not query:
            print('cannot read the whole table')
            return None

        segs = []
        for x in collection.find(query):
            x['data'] = self.deser(x['data'], x['ver'])
            segs.append(x)
        segs.sort(key=lambda x: (x['symbol'], x['date'], x['start']))
        return pd.concat([x['data'] for x in segs], ignore_index=True) if segs else None

    def list_tables(self):
        return self.db.collection_names()

    def list_dates(self, table_name, start_date=None, end_date=None, symbol=None):
        collection = self.db[table_name]
        dates = set()
        if start_date is None:
            start_date = '00000000'
        if end_date is None:
            end_date = '99999999'
        for x in collection.find(self.build_query(start_date, end_date, symbol), {"date": 1, '_id': 0}):
            dates.add(x['date'])
        return sorted(list(dates))

    def ser(self, s, version):
        pickle_protocol = 4
        if version == 1:
            return gzip.compress(pickle.dumps(s, protocol=pickle_protocol), compresslevel=2)
        elif version == 2:
            return lzma.compress(pickle.dumps(s, protocol=pickle_protocol), preset=1)
        else:
            raise Exception('unknown version')

    def deser(self, s, version):
        def unpickle(s):
            return pickle.loads(s)

        if version == 1:
            return unpickle(gzip.decompress(s))
        elif version == 2:
            return unpickle(lzma.decompress(s))
        else:
            raise Exception('unknown version')


def patch_pandas_pickle():
    if pd.__version__ < '0.24':
        import sys
        from types import ModuleType
        from pandas.core.internals import BlockManager
        pkg_name = 'pandas.core.internals.managers'
        if pkg_name not in sys.modules:
            m = ModuleType(pkg_name)
            m.BlockManager = BlockManager
            sys.modules[pkg_name] = m
patch_pandas_pickle()
    
    


import pandas as pd
import random
import numpy as np
import glob
import os
import pickle
import datetime
import time
pd.set_option("max_columns", 200)

startTm = datetime.datetime.now()
readPath = '/home/work516/day_stock/***'
dataPathLs = np.array(glob.glob(readPath))
dataPathLs = dataPathLs[[np.array([os.path.basename(i).split('.')[0][:2] == 'SZ' for i in dataPathLs])]]
db = pd.DataFrame()
for p in dataPathLs:
    dayData = pd.read_csv(p, compression='gzip')
    db = pd.concat([db, dayData])
print(datetime.datetime.now() - startTm)

year = "2020"
startDate = '20200921'
endDate = '20200921'
readPath = '/mnt/usb/data/' + year + '/***/***'
dataPathLs = np.array(glob.glob(readPath))
dateLs = np.array([os.path.basename(i) for i in dataPathLs])
dataPathLs = dataPathLs[(dateLs >= startDate) & (dateLs <= endDate)]
less = []

for data in dataPathLs:
    
    
    if len(np.array(glob.glob(data + '/SZ/***'))) == 0:
        if int(os.path.basename(data)) not in date_list["Date"].values:
            continue
        else:
            print(os.path.basename(data) + " less data!!!!!!!!!!!!!!!!!")
            less.append(data)
            continue
    startTm = datetime.datetime.now()
    date = os.path.basename(data)
    rar_path = data + '/SZ/order.7z'
    path = '/mnt/e/unzip_data/2020/SZ'
    path1 = path + '/' + date
    un_path = path1
    cmd = '7za x {} -o{}'.format(rar_path, un_path)
    os.system(cmd)
    print(datetime.datetime.now() - startTm)
    print(date + ' unzip finished')
    
    
    startTm = datetime.datetime.now()
    
    readPath = path1 + '/order/***'
    dataPathLs = np.array(glob.glob(readPath))
    dateLs = np.array([int(os.path.basename(i).split('.')[0]) for i in dataPathLs])
    dataPathLs = dataPathLs[(dateLs < 4000) | ((dateLs > 300000) & (dateLs < 310000))]
    OrderLog = []
    ll = []
    
    for i in dataPathLs:
        try:
            df = pd.read_csv(i, encoding='GBK')
        except:
            print("empty data")
            print(i)
            ll.append(int(os.path.basename(i).split('.')[0]))
            continue
        df["SecurityID"] = int(os.path.basename(i).split('.')[0])
        OrderLog += [df]
    OrderLog = pd.concat(OrderLog).reset_index(drop=True)
    OrderLog = OrderLog[OrderLog["ChannelNo"] != 4001]
    
    OrderLog = OrderLog.rename(columns={"OrdType": "OrderType"})
    OrderLog["date"] = OrderLog["TransactTime"].iloc[0]//1000000000
    OrderLog["OrderType"] = np.where(OrderLog["OrderType"] == 'U', 3, OrderLog["OrderType"])
    OrderLog["skey"] = OrderLog["SecurityID"] + 2000000
    OrderLog["clockAtArrival"] = OrderLog["TransactTime"].astype(str).apply(lambda x: np.int64(datetime.datetime.strptime(x, '%Y%m%d%H%M%S%f').timestamp()*1e6))
    OrderLog['datetime'] = OrderLog["clockAtArrival"].apply(lambda x: datetime.datetime.fromtimestamp(x/1e6))
    OrderLog["time"] = (OrderLog['TransactTime'] - int(OrderLog['TransactTime'].iloc[0]//1000000000*1000000000)).astype(np.int64)*1000
    
    for col in ["skey", "date", "ApplSeqNum", "OrderQty", "Side", "OrderType"]:
        OrderLog[col] = OrderLog[col].astype('int32')
#     for cols in ["Price"]:
#         print(cols)
#         print(OrderLog[cols].astype(str).apply(lambda x: len(str(x.split('.')[1]))).unique())
    
    assert(OrderLog[((OrderLog["Side"] != 1) & (OrderLog["Side"] != 2)) | (OrderLog["OrderType"].isnull())].shape[0] == 0)
    da_te = str(OrderLog["date"].iloc[0]) 
    da_te = da_te[:4] + '-' + da_te[4:6] + '-' + da_te[6:8]
    db1 = db[db["date"] == da_te]
    sl = (db1["ID"].str[2:].astype(int) + 2000000).unique()
    del db1
    try:
        assert(len(set(sl) - set(OrderLog["skey"].unique())) == 0)
    except:
        print("less stocks")
        display(set(sl) - set(OrderLog["skey"].unique()))
    if len(set(OrderLog["skey"].unique()) - set(sl)) != 0:
        print("more stocks")
        print(set(OrderLog["skey"].unique()) - set(sl))
    
    OrderLog = OrderLog.rename(columns={"Side":"order_side", "OrderType":"order_type", "Price":"order_price", "OrderQty":"order_qty"})
    OrderLog = OrderLog[["skey", "date", "time", "clockAtArrival", "datetime", "ApplSeqNum", "order_side", "order_type", "order_price",
                                                 "order_qty"]]
    
    print(OrderLog["date"].iloc[0])
    print("order finished")

    database_name = 'com_md_eq_cn'
    user = "zhenyuy"
    password = "bnONBrzSMGoE"

    db1 = DB("192.168.10.178", database_name, user, password)
    db1.write('md_order', OrderLog)
    
    del OrderLog
    
    print(datetime.datetime.now() - startTm)
    
#     pd.set_option("max_rows", 200)
#     display(OrderLog.dtypes)
# Out:
# /home/work516/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:195: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
# 0:05:55.159125
# 0:00:00.511390
# 20200306 unzip finished
# /home/work516/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (1) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /home/work516/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (4) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /home/work516/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (1,4) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# 20200306
# order finished
# 0:18:41.332081
# 0:00:00.736980
# 20200309 unzip finished
# 20200309
# order finished
# 0:19:36.345457
# 0:00:00.655396
# 20200310 unzip finished
# 20200310
# order finished
# 0:20:28.706706
# 0:00:00.987282
# 20200311 unzip finished
# 20200311
# order finished
# 0:19:01.248269
# 0:00:00.761123
# 20200312 unzip finished
# 20200312
# order finished
# 0:18:03.373737
# 0:00:00.812867
# 20200313 unzip finished
# 20200313
# order finished
# 0:19:13.364142
# 0:00:43.698348
# 20200316 unzip finished
# 20200316
# order finished
# 0:17:44.845210
# 0:00:41.019928
# 20200317 unzip finished
# 20200317
# order finished
# 0:16:27.203112
# 0:00:38.540766
# 20200318 unzip finished
# 20200318
# order finished
# 0:15:39.913956
# 0:00:39.835759
# 20200319 unzip finished
# 20200319
# order finished
# 0:16:02.127582
# 0:00:36.744708
# 20200320 unzip finished
# 20200320
# order finished
# 0:14:02.231148
# 0:00:34.543847
# 20200323 unzip finished
# 20200323
# order finished
# 0:14:18.021769
# 0:00:35.897718
# 20200324 unzip finished
# 20200324
# order finished
# 0:15:23.388750
# 0:00:39.211355
# 20200325 unzip finished
# 20200325
# order finished
# 0:14:15.944270
# 0:00:36.187563
# 20200326 unzip finished
# 20200326
# order finished
# 0:13:50.814482
# 0:00:34.225862
# 20200327 unzip finished
# 20200327
# order finished
# 0:14:02.508546
# 0:00:33.860789
# 20200330 unzip finished
# 20200330
# order finished
# 0:13:16.771562
# 0:00:34.798773
# 20200331 unzip finished
# 20200331
# order finished
# 0:12:25.154568
# 0:00:37.540695
# 20200401 unzip finished
# 20200401
# order finished
# 0:12:34.833342
# 0:00:33.481606
# 20200402 unzip finished
# 20200402
# order finished
# 0:12:38.699264
# 0:00:31.980876
# 20200403 unzip finished
# 20200403
# order finished
# 0:12:19.319114
# 0:00:35.689331
# 20200407 unzip finished
# 20200407
# order finished
# 0:14:02.384171
# 0:00:37.106345
# 20200408 unzip finished
# 20200408
# order finished
# 0:14:01.264228
# 0:00:33.845092
# 20200409 unzip finished
# 20200409
# order finished
# 0:13:17.551685
# 0:00:37.612850
# 20200410 unzip finished
# 20200410
# order finished
# 0:14:16.635406
# 0:00:31.360201
# 20200413 unzip finished
# 20200413
# order finished
# 0:11:09.233916
# 0:00:29.640397
# 20200414 unzip finished
# /home/work516/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (12) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# 20200414
# order finished
# 0:11:42.663491
# 0:00:34.275717
# 20200415 unzip finished
# 20200415
# order finished
# 0:13:36.294398
# 0:00:30.581440
# 20200416 unzip finished
# 20190416
# order finished
# 0:13:06.720086
# 0:00:40.116644
# 20200417 unzip finished
# 20200417
# order finished
# 0:14:49.640829
# 0:00:34.229391
# 20200420 unzip finished
# 20200420
# order finished
# 0:13:25.882979
# 0:00:39.327535
# 20200421 unzip finished
# 20200421
# order finished
# 0:13:56.897412
# 0:00:34.451184
# 20200422 unzip finished
# 20200422
# order finished
# 0:12:57.193577
# 0:00:38.438343
# 20200423 unzip finished
# 20200423
# order finished
# 0:13:42.303795
# 0:00:36.281647
# 20200424 unzip finished
# 20200424
# order finished
# 0:13:56.043189
# 0:00:30.569501
# 20200427 unzip finished
# 20200427
# order finished
# 0:11:49.701807
# 0:00:35.307876
# 20200428 unzip finished
# 20200428
# order finished
# 0:14:15.434137
# 0:00:31.495844
# 20200429 unzip finished
# 20200429
# order finished
# 0:11:40.860533
# 0:00:35.402774
# 20200430 unzip finished
# 20200430
# order finished
# 0:13:04.346610
# 0:00:33.265327
# 20200506 unzip finished
# 20200506
# order finished
# 0:13:07.182700
# 0:00:32.636789
# 20200507 unzip finished
# 20200507
# order finished
# 0:12:49.393847
# 0:00:34.082353
# 20200508 unzip finished
# 20200508
# order finished
# 0:13:00.312058
# 0:00:35.152464
# 20200511 unzip finished
# 20200511
# order finished
# 0:13:00.918193
# 0:00:32.790253
# 20200512 unzip finished
# 20200512
# order finished
# 0:12:51.850837
# 0:00:37.274358
# 20200513 unzip finished
# 20200513
# order finished
# 0:11:51.402940
# 0:00:32.996162
# 20200514 unzip finished
# 20200514
# order finished
# 0:11:55.850826
# 0:00:32.495521
# 20200515 unzip finished
# 20200515
# order finished
# 0:11:39.491344
# 0:00:38.993854
# 20200518 unzip finished
# 20200518
# order finished
# 0:13:04.790782
# 0:00:32.896302
# 20200519 unzip finished
# 20200519
# order finished
# 0:11:56.516863
# 0:00:33.941603
# 20200520 unzip finished
# 20200520
# order finished
# 0:12:37.780973
# 0:00:32.815081
# 20200521 unzip finished
# 20200521
# order finished
# 0:12:17.905712
# 0:00:40.753751
# 20200522 unzip finished
# 20200522
# order finished
# 0:11:51.764254
# 0:00:20.793865
# 20200525 unzip finished
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000001.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000002.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000004.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000005.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000006.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000007.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000008.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000009.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000010.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000011.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000012.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000014.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000016.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000017.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000019.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000020.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000021.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000023.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000025.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000026.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000027.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000028.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000030.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000031.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000032.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000034.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000035.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000036.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000037.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000038.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000039.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000040.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000042.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000045.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000046.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000048.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000049.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000050.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000055.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000056.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000058.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000059.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000060.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000061.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000062.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000063.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000065.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000066.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000068.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000069.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000070.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000078.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000088.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000089.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000090.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000096.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000099.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000100.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000150.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000151.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000153.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000156.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000157.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000158.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000159.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000166.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000301.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000333.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000338.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000400.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000401.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000402.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000403.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000404.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000407.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000408.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000409.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000410.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000411.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000413.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000415.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000416.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000417.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000419.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000420.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000421.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000422.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000423.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000425.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000426.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000428.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000429.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000430.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000488.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000498.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000501.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000502.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000503.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000504.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000505.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000506.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000507.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000509.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000510.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000513.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000514.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000516.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000517.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000518.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000519.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000520.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000521.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000523.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000524.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000525.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000526.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000528.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000529.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000530.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000531.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000532.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000533.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000534.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000536.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000537.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000538.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000539.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000540.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000541.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000543.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000544.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000545.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000546.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000547.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000548.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000550.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000551.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000552.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000553.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000554.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000555.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000557.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000558.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000559.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000560.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000561.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000563.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000564.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000565.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000566.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000567.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000568.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000570.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000571.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000572.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000573.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000576.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000581.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000582.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000584.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000585.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000586.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000587.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000589.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000590.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000591.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000592.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000593.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000595.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000596.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000597.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000598.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000599.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000600.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000601.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000603.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000605.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000606.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000607.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000608.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000609.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000610.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000611.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000612.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000613.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000615.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000616.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000617.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000619.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000620.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000622.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000623.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000625.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000626.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000627.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000628.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000629.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000630.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000631.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000632.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000633.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000635.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000636.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000637.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000638.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000639.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000650.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000651.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000652.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000655.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000656.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000657.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000659.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000661.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000662.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000663.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000665.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000666.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000667.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000669.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000671.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000672.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000673.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000676.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000677.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000678.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000679.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000680.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000681.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000682.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000683.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000685.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000686.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000687.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000688.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000690.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000691.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000692.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000695.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000697.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000698.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000700.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000701.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000702.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000703.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000705.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000707.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000708.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000709.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000710.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000711.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000712.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000713.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000715.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000716.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000717.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000718.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000719.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000720.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000721.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000722.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000723.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000725.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000726.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000727.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000728.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000729.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000731.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000732.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000733.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000735.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000736.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000737.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000738.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000739.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000750.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000751.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000752.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000753.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000755.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000756.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000757.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000758.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000759.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000760.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000761.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000762.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000766.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000767.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000768.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000776.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000777.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000778.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000779.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000780.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000782.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000783.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000785.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000786.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000788.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000789.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000790.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000791.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000793.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000795.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000796.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000797.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000798.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000799.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000800.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000801.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000802.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000803.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000806.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000807.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000809.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000810.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000811.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000812.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000813.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000815.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000816.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000818.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000819.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000820.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000821.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000822.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000823.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000825.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000826.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000828.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000829.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000830.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000831.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000833.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000835.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000836.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000837.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000838.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000839.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000848.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000850.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000851.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000852.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000856.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000858.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000859.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000860.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000861.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000862.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000863.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000868.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000869.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000875.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000876.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000877.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000878.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000880.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000881.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000882.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000883.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000885.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000886.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000887.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000888.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000889.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000890.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000892.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000893.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000895.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000897.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000898.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000899.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000900.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000901.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000902.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000903.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000905.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000906.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000908.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000909.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000910.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000911.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000912.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000913.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000915.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000917.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000918.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000919.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000920.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000921.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000922.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000923.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000925.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000926.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000927.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000928.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000929.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000930.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000931.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000932.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000933.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000935.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000936.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000937.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000938.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000948.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000949.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000950.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000951.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000952.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000953.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000955.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000957.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000958.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000959.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000960.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000961.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000962.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000963.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000965.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000966.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000967.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000968.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000969.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000970.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000971.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000972.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000973.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000975.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000976.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000977.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000978.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000980.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000981.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000982.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000983.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000985.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000987.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000988.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000989.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000990.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000993.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000996.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000997.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000998.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/000999.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/001696.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/001872.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/001896.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/001914.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/001965.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/001979.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002001.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002002.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002003.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002004.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002005.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002006.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002007.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002008.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002009.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002010.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002011.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002012.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002013.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002014.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002015.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002016.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002017.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002019.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002020.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002021.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002022.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002023.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002024.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002025.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002026.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002027.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002028.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002029.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002030.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002031.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002032.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002033.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002034.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002035.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002036.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002037.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002038.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002039.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002040.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002041.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002042.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002043.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002044.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002045.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002046.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002047.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002048.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002049.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002050.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002051.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002052.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002053.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002054.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002055.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002056.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002057.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002058.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002059.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002060.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002061.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002062.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002063.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002064.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002065.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002066.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002067.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002068.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002069.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002071.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002072.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002073.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002075.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002076.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002077.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002078.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002079.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002080.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002081.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002082.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002083.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002084.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002085.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002086.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002087.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002088.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002089.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002090.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002091.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002092.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002093.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002094.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002095.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002096.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002097.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002098.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002099.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002100.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002101.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002102.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002103.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002104.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002105.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002106.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002107.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002108.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002109.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002110.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002111.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002112.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002113.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002114.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002115.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002116.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002117.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002118.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002119.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002120.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002121.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002122.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002123.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002124.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002125.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002126.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002127.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002128.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002129.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002130.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002131.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002132.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002133.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002134.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002135.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002136.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002137.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002138.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002139.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002140.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002141.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002142.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002144.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002145.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002146.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002147.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002148.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002149.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002150.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002151.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002152.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002153.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002154.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002155.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002156.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002157.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002158.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002159.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002160.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002161.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002162.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002163.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002164.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002165.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002166.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002167.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002168.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002169.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002170.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002171.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002172.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002173.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002174.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002175.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002176.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002177.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002178.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002179.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002180.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002181.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002182.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002183.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002184.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002185.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002186.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002187.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002188.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002189.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002190.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002191.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002192.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002193.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002194.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002195.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002196.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002197.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002198.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002199.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002200.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002201.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002202.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002203.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002204.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002205.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002206.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002207.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002208.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002209.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002210.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002211.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002212.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002213.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002214.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002215.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002216.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002217.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002218.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002219.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002220.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002221.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002222.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002223.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002224.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002225.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002226.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002227.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002228.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002229.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002230.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002231.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002232.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002233.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002234.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002235.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002236.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002237.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002238.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002239.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002240.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002241.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002242.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002243.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002244.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002245.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002246.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002247.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002248.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002249.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002250.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002251.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002252.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002253.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002254.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002256.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002258.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002259.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002261.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002262.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002267.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002268.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002269.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002270.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002273.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002276.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002278.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002279.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002281.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002285.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002292.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/002990.csv
# empty data
# /mnt/e/unzip_data/2020/SZ/20200525/order/300835.csv
# less stocks
# {2000001,
#  2000002,
#  2000004,
#  2000005,
#  2000006,
#  2000007,
#  2000008,
#  2000009,
#  2000010,
#  2000011,
#  2000012,
#  2000014,
#  2000016,
#  2000017,
#  2000019,
#  2000020,
#  2000021,
#  2000023,
#  2000025,
#  2000026,
#  2000027,
#  2000028,
#  2000030,
#  2000031,
#  2000032,
#  2000034,
#  2000035,
#  2000036,
#  2000037,
#  2000038,
#  2000039,
#  2000040,
#  2000042,
#  2000045,
#  2000046,
#  2000048,
#  2000049,
#  2000050,
#  2000055,
#  2000056,
#  2000058,
#  2000059,
#  2000060,
#  2000061,
#  2000062,
#  2000063,
#  2000065,
#  2000066,
#  2000068,
#  2000069,
#  2000070,
#  2000078,
#  2000088,
#  2000089,
#  2000090,
#  2000096,
#  2000099,
#  2000100,
#  2000150,
#  2000151,
#  2000153,
#  2000156,
#  2000157,
#  2000158,
#  2000159,
#  2000166,
#  2000301,
#  2000333,
#  2000338,
#  2000400,
#  2000401,
#  2000402,
#  2000403,
#  2000404,
#  2000407,
#  2000408,
#  2000409,
#  2000410,
#  2000411,
#  2000413,
#  2000415,
#  2000416,
#  2000417,
#  2000419,
#  2000420,
#  2000421,
#  2000422,
#  2000423,
#  2000425,
#  2000426,
#  2000428,
#  2000429,
#  2000430,
#  2000488,
#  2000498,
#  2000501,
#  2000502,
#  2000503,
#  2000504,
#  2000505,
#  2000506,
#  2000507,
#  2000509,
#  2000510,
#  2000513,
#  2000514,
#  2000516,
#  2000517,
#  2000518,
#  2000519,
#  2000520,
#  2000521,
#  2000523,
#  2000524,
#  2000525,
#  2000526,
#  2000528,
#  2000529,
#  2000530,
#  2000531,
#  2000532,
#  2000533,
#  2000534,
#  2000536,
#  2000537,
#  2000538,
#  2000539,
#  2000540,
#  2000541,
#  2000543,
#  2000544,
#  2000545,
#  2000546,
#  2000547,
#  2000548,
#  2000550,
#  2000551,
#  2000552,
#  2000553,
#  2000554,
#  2000555,
#  2000557,
#  2000558,
#  2000559,
#  2000560,
#  2000561,
#  2000563,
#  2000564,
#  2000565,
#  2000566,
#  2000567,
#  2000568,
#  2000570,
#  2000571,
#  2000572,
#  2000573,
#  2000576,
#  2000581,
#  2000582,
#  2000584,
#  2000585,
#  2000586,
#  2000587,
#  2000589,
#  2000590,
#  2000591,
#  2000592,
#  2000593,
#  2000595,
#  2000596,
#  2000597,
#  2000598,
#  2000599,
#  2000600,
#  2000601,
#  2000603,
#  2000605,
#  2000606,
#  2000607,
#  2000608,
#  2000609,
#  2000610,
#  2000611,
#  2000612,
#  2000613,
#  2000615,
#  2000616,
#  2000617,
#  2000619,
#  2000620,
#  2000622,
#  2000623,
#  2000625,
#  2000626,
#  2000627,
#  2000628,
#  2000629,
#  2000630,
#  2000631,
#  2000632,
#  2000633,
#  2000635,
#  2000636,
#  2000637,
#  2000638,
#  2000639,
#  2000650,
#  2000651,
#  2000652,
#  2000655,
#  2000656,
#  2000657,
#  2000659,
#  2000661,
#  2000662,
#  2000663,
#  2000665,
#  2000666,
#  2000667,
#  2000669,
#  2000671,
#  2000672,
#  2000673,
#  2000676,
#  2000677,
#  2000678,
#  2000679,
#  2000680,
#  2000681,
#  2000682,
#  2000683,
#  2000685,
#  2000686,
#  2000687,
#  2000688,
#  2000690,
#  2000691,
#  2000692,
#  2000695,
#  2000697,
#  2000698,
#  2000700,
#  2000701,
#  2000702,
#  2000703,
#  2000705,
#  2000707,
#  2000708,
#  2000709,
#  2000710,
#  2000711,
#  2000712,
#  2000713,
#  2000715,
#  2000716,
#  2000717,
#  2000718,
#  2000719,
#  2000720,
#  2000721,
#  2000722,
#  2000723,
#  2000725,
#  2000726,
#  2000727,
#  2000728,
#  2000729,
#  2000731,
#  2000732,
#  2000733,
#  2000735,
#  2000736,
#  2000737,
#  2000738,
#  2000739,
#  2000750,
#  2000751,
#  2000752,
#  2000753,
#  2000755,
#  2000756,
#  2000757,
#  2000758,
#  2000759,
#  2000760,
#  2000761,
#  2000762,
#  2000766,
#  2000767,
#  2000768,
#  2000776,
#  2000777,
#  2000778,
#  2000779,
#  2000780,
#  2000782,
#  2000783,
#  2000785,
#  2000786,
#  2000788,
#  2000789,
#  2000790,
#  2000791,
#  2000793,
#  2000795,
#  2000796,
#  2000797,
#  2000798,
#  2000799,
#  2000800,
#  2000801,
#  2000802,
#  2000803,
#  2000806,
#  2000807,
#  2000809,
#  2000810,
#  2000811,
#  2000812,
#  2000813,
#  2000815,
#  2000816,
#  2000818,
#  2000819,
#  2000820,
#  2000821,
#  2000822,
#  2000823,
#  2000825,
#  2000826,
#  2000828,
#  2000829,
#  2000830,
#  2000831,
#  2000833,
#  2000835,
#  2000836,
#  2000837,
#  2000838,
#  2000839,
#  2000848,
#  2000850,
#  2000851,
#  2000852,
#  2000856,
#  2000858,
#  2000859,
#  2000860,
#  2000861,
#  2000862,
#  2000863,
#  2000868,
#  2000869,
#  2000875,
#  2000876,
#  2000877,
#  2000878,
#  2000880,
#  2000881,
#  2000882,
#  2000883,
#  2000885,
#  2000886,
#  2000887,
#  2000888,
#  2000889,
#  2000890,
#  2000892,
#  2000893,
#  2000895,
#  2000897,
#  2000898,
#  2000899,
#  2000900,
#  2000901,
#  2000902,
#  2000903,
#  2000905,
#  2000906,
#  2000908,
#  2000909,
#  2000910,
#  2000911,
#  2000912,
#  2000913,
#  2000915,
#  2000917,
#  2000918,
#  2000919,
#  2000920,
#  2000921,
#  2000922,
#  2000923,
#  2000925,
#  2000926,
#  2000927,
#  2000928,
#  2000929,
#  2000930,
#  2000931,
#  2000932,
#  2000933,
#  2000935,
#  2000936,
#  2000937,
#  2000938,
#  2000948,
#  2000949,
#  2000950,
#  2000951,
#  2000952,
#  2000953,
#  2000955,
#  2000957,
#  2000958,
#  2000959,
#  2000960,
#  2000961,
#  2000962,
#  2000963,
#  2000965,
#  2000966,
#  2000967,
#  2000968,
#  2000969,
#  2000970,
#  2000971,
#  2000972,
#  2000973,
#  2000975,
#  2000976,
#  2000977,
#  2000978,
#  2000980,
#  2000981,
#  2000982,
#  2000983,
#  2000985,
#  2000987,
#  2000988,
#  2000989,
#  2000990,
#  2000993,
#  2000996,
#  2000997,
#  2000998,
#  2000999,
#  2001696,
#  2001872,
#  2001896,
#  2001914,
#  2001965,
#  2001979,
#  2002001,
#  2002002,
#  2002003,
#  2002004,
#  2002005,
#  2002006,
#  2002007,
#  2002008,
#  2002009,
#  2002010,
#  2002011,
#  2002012,
#  2002013,
#  2002014,
#  2002015,
#  2002016,
#  2002017,
#  2002019,
#  2002020,
#  2002021,
#  2002022,
#  2002023,
#  2002024,
#  2002025,
#  2002026,
#  2002027,
#  2002028,
#  2002029,
#  2002030,
#  2002031,
#  2002032,
#  2002033,
#  2002034,
#  2002035,
#  2002036,
#  2002037,
#  2002038,
#  2002039,
#  2002040,
#  2002041,
#  2002042,
#  2002043,
#  2002044,
#  2002045,
#  2002046,
#  2002047,
#  2002048,
#  2002049,
#  2002050,
#  2002051,
#  2002052,
#  2002053,
#  2002054,
#  2002055,
#  2002056,
#  2002057,
#  2002058,
#  2002059,
#  2002060,
#  2002061,
#  2002062,
#  2002063,
#  2002064,
#  2002065,
#  2002066,
#  2002067,
#  2002068,
#  2002069,
#  2002071,
#  2002072,
#  2002073,
#  2002075,
#  2002076,
#  2002077,
#  2002078,
#  2002079,
#  2002080,
#  2002081,
#  2002082,
#  2002083,
#  2002084,
#  2002085,
#  2002086,
#  2002087,
#  2002088,
#  2002089,
#  2002090,
#  2002091,
#  2002092,
#  2002093,
#  2002094,
#  2002095,
#  2002096,
#  2002097,
#  2002098,
#  2002099,
#  2002100,
#  2002101,
#  2002102,
#  2002103,
#  2002104,
#  2002105,
#  2002106,
#  2002107,
#  2002108,
#  2002109,
#  2002110,
#  2002111,
#  2002112,
#  2002113,
#  2002114,
#  2002115,
#  2002116,
#  2002117,
#  2002118,
#  2002119,
#  2002120,
#  2002121,
#  2002122,
#  2002123,
#  2002124,
#  2002125,
#  2002126,
#  2002127,
#  2002128,
#  2002129,
#  2002130,
#  2002131,
#  2002132,
#  2002133,
#  2002134,
#  2002135,
#  2002136,
#  2002137,
#  2002138,
#  2002139,
#  2002140,
#  2002141,
#  2002142,
#  2002144,
#  2002145,
#  2002146,
#  2002147,
#  2002148,
#  2002149,
#  2002150,
#  2002151,
#  2002152,
#  2002153,
#  2002154,
#  2002155,
#  2002156,
#  2002157,
#  2002158,
#  2002159,
#  2002160,
#  2002161,
#  2002162,
#  2002163,
#  2002164,
#  2002165,
#  2002166,
#  2002167,
#  2002168,
#  2002169,
#  2002170,
#  2002171,
#  2002172,
#  2002173,
#  2002174,
#  2002175,
#  2002176,
#  2002177,
#  2002178,
#  2002179,
#  2002180,
#  2002181,
#  2002182,
#  2002183,
#  2002184,
#  2002185,
#  2002186,
#  2002187,
#  2002188,
#  2002189,
#  2002190,
#  2002191,
#  2002192,
#  2002193,
#  2002194,
#  2002195,
#  2002196,
#  2002197,
#  2002198,
#  2002199,
#  2002200,
#  2002201,
#  2002202,
#  2002203,
#  2002204,
#  2002205,
#  2002206,
#  2002207,
#  2002208,
#  2002209,
#  2002210,
#  2002211,
#  2002212,
#  2002213,
#  2002214,
#  2002215,
#  2002216,
#  2002217,
#  2002218,
#  2002219,
#  2002220,
#  2002221,
#  2002222,
#  2002223,
#  2002224,
#  2002225,
#  2002226,
#  2002227,
#  2002228,
#  2002229,
#  2002230,
#  2002231,
#  2002232,
#  2002233,
#  2002234,
#  2002235,
#  2002236,
#  2002237,
#  2002238,
#  2002239,
#  2002240,
#  2002241,
#  2002242,
#  2002243,
#  2002244,
#  2002245,
#  2002246,
#  2002247,
#  2002248,
#  2002249,
#  2002250,
#  2002251,
#  2002252,
#  2002253,
#  2002254,
#  2002256,
#  2002258,
#  2002259,
#  2002261,
#  2002262,
#  2002267,
#  2002268,
#  2002269,
#  2002270,
#  2002273,
#  2002276,
#  2002278,
#  2002279,
#  2002281,
#  2002285,
#  2002292,
#  2002990,
#  2300835}
# 20200525
# order finished
# 0:07:29.162645
# 0:00:28.292068
# 20200526 unzip finished
# empty data
# /mnt/e/unzip_data/2020/SZ/20200526/order/300572.csv
# less stocks
# {2300572}
# 20200526
# order finished
# 0:10:41.732702
# 0:00:29.517023
# 20200527 unzip finished
# 20200527
# order finished
# 0:11:08.298081
# 0:00:30.972830
# 20200528 unzip finished
# 20200528
# order finished
# 0:11:12.746827
# 0:00:30.220232
# 20200529 unzip finished
# 20200529
# order finished
# 0:11:29.401821
